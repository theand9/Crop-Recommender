# %%
import pandas as pd
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly import tools

init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
path1 = "C:/Users/pooja/Desktop/Project/final_Clean_data/Soil/Akola.csv"
df_Soil=pd.read_csv(path1)

soil1 = go.Bar(
    x = df_Soil.Village.head(15),
    y = df_Soil.pH,
    
    name = "pH",
    marker=dict(
        color= "red"
    ),
)

soil2 = go.Bar(
    x = df_Soil.Village.head(15),
    y = df_Soil.N/100,
    
    name = "N  Scale = 1:100",
    marker=dict(
        color= "orange"
    )
)

soil3 = go.Bar(
    x = df_Soil.Village.head(15),
    y = df_Soil.P/10,
    
    name = "P  Scale = 1:10",
    marker=dict(
        color= "yellow"
    )
)

soil4 = go.Bar(
    x = df_Soil.Village.head(10),
    y = df_Soil.K/100,
    
    name = "K  Scale = 1:100",
    marker=dict(
        color= "green"
    )
)

soil5 = go.Bar(
    x = df_Soil.Village.head(15),
    y = df_Soil.OC,
    
    name = "OC",
    marker=dict(
        color= "lightblue"
    )
)

soil6 = go.Bar(
    x = df_Soil.Village.head(15),
    y = df_Soil.Fe,
    
    name = "Fe",
    marker=dict(
        color= "blue"
    )
)

layout = go.Layout(
    barmode = 'group',
    paper_bgcolor='black', 
    plot_bgcolor='black',
    xaxis=dict(
        tickcolor='white',
        titlefont=dict(
            color='white'
        ),
        showticklabels=True,
        tickfont=dict(
            color='white'
        ),
        linecolor='white',
        gridcolor="gray",
    ),
    yaxis=dict(
        tickcolor='white',
        titlefont=dict(
            color='white'
        ),
        showticklabels=True,
        tickfont=dict(
            color='white'
        ),
        linecolor='white',
        gridcolor="gray",
    ),
    
    legend=dict(
        font=dict(
            color="white",
        ),
    )
)

data = [soil1, soil2, soil3, soil4, soil5, soil6]
fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='grouped-bar')
# Out:
# <div id="0e5cad02-1f5b-4df1-975f-3113a6b87bd8" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("0e5cad02-1f5b-4df1-975f-3113a6b87bd8")) {
# ...

# %%
path2 = "C:/Users/pooja/Desktop/Project/final_Clean_data/Weather Pooja/Rainfall/Akola.csv"
path3 = "C:/Users/pooja/Desktop/Project/final_Clean_data/Weather Pooja/Temperature/Akola.csv"
path4 = "C:/Users/pooja/Desktop/Project/final_Clean_data/Weather Pooja/Humidity/Akola.csv"

df_rain = pd.read_csv(path2)
df_temp = pd.read_csv(path3)
df_humid = pd.read_csv(path4)

trace1 = go.Scatter(x=df_rain.Year.head(50), y=df_rain.Jan, name="Jan (Rainfall mm)")
trace2 = go.Scatter(x=df_rain.Year.head(50), y=df_rain.Feb, name="Feb (Rainfall mm)")
trace3 = go.Scatter(x=df_rain.Year.head(50), y=df_rain.Mar, name="Mar (Rainfall mm)")
trace4 = go.Scatter(x=df_rain.Year.head(50), y=df_rain.Apr, name="Apr (Rainfall mm)")
trace5 = go.Scatter(x=df_rain.Year.head(50), y=df_rain.May, name="May (Rainfall mm)")
trace6 = go.Scatter(x=df_rain.Year.head(50), y=df_rain.Jun, name="Jun (Rainfall mm)")
trace7 = go.Scatter(x=df_rain.Year.head(50), y=df_rain.Jul, name="Jul (Rainfall mm)")
trace8 = go.Scatter(x=df_rain.Year.head(50), y=df_rain.Aug, name="Aug (Rainfall mm)")
trace9 = go.Scatter(x=df_rain.Year.head(50), y=df_rain.Sep, name="Sep (Rainfall mm)")
trace10 = go.Scatter(x=df_rain.Year.head(50), y=df_rain.Oct, name="Oct (Rainfall mm)")
trace11 = go.Scatter(x=df_rain.Year.head(50), y=df_rain.Nov, name="Nov (Rainfall mm)")
trace12 = go.Scatter(x=df_rain.Year.head(50), y=df_rain.Dec, name="Dec (Rainfall mm)")

fig = tools.make_subplots(rows=4, cols=3, subplot_titles=('Jan', 'Feb',
                                                          'Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'))

fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)
fig.append_trace(trace3, 1, 3)
fig.append_trace(trace4, 2, 1)
fig.append_trace(trace5, 2, 2)
fig.append_trace(trace6, 2, 3)
fig.append_trace(trace7, 3, 1)
fig.append_trace(trace8, 3, 2)
fig.append_trace(trace9, 3, 3)
fig.append_trace(trace10, 4, 1)
fig.append_trace(trace11, 4, 2)
fig.append_trace(trace12, 4, 3)

fig['layout'].update(height=900, width=1000, title='Rainfall in Maharashtra')
iplot(fig, filename='make-subplots-multiple-with-titles')
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]    [ (1,2) x2,y2 ]    [ (1,3) x3,y3 ]
# [ (2,1) x4,y4 ]    [ (2,2) x5,y5 ]    [ (2,3) x6,y6 ]
# [ (3,1) x7,y7 ]    [ (3,2) x8,y8 ]    [ (3,3) x9,y9 ]
# [ (4,1) x10,y10 ]  [ (4,2) x11,y11 ]  [ (4,3) x12,y12 ]
# <div id="43ef85c3-3c3f-4280-9f86-63a05b730204" style="height: 900px; width: 1000px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("43ef85c3-3c3f-4280-9f86-63a05b730204")) {
# ...

# %%
path5 = "C:/Users/pooja/Desktop/Project/final_Clean_data/Crops/FinalCosts.csv"
df_cost = pd.read_csv(path5)

trace0 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Arhar"],
    y=df_cost.Cultivation_Cost[df_cost["Crop"] == "Arhar"],
    mode='markers',
    name = "Cost of Cultivation",
    marker=dict(
        color="red",
        size=20
    
    ),
)

trace1 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Arhar"],
    y=df_cost.MSP[df_cost["Crop"] == "Arhar"],
    mode='markers',
    name = "MSP",
    marker=dict(
        color="blue",
        size=20
    ),
)
#----------------------------------------------------------------

trace2 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Bajra"],
    y=df_cost.Cultivation_Cost[df_cost["Crop"] == "Bajra"],
    mode='markers',
    name = "Cost of Cultivation",
    showlegend=False,
    marker=dict(
        color="red",
        size=20
    ),
)

trace3 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Bajra"],
    y=df_cost.MSP[df_cost["Crop"] == "Bajra"],
    mode='markers',
    name = "MSP",
    showlegend=False,
    marker=dict(
        color="blue",
        size=20
    ),
)
#---------------------------------------------------------------------
trace4 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Cotton"],
    y=df_cost.Cultivation_Cost[df_cost["Crop"] == "Cotton"],
    mode='markers',
    name = "Cost of Cultivation",
    showlegend=False,
    marker=dict(
        color="red",
        size=20
    ),
)

trace5 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Cotton"],
    y=df_cost.MSP[df_cost["Crop"] == "Cotton"],
    mode='markers',
    name = "MSP",
    showlegend=False,
    marker=dict(
        color="blue",
        size=20
    ),
)
#-----------------------------------------------------------------------------------------

trace6 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Gram"],
    y=df_cost.Cultivation_Cost[df_cost["Crop"] == "Gram"],
    mode='markers',
    name = "Cost of Cultivation",
    showlegend=False,
    marker=dict(
        color="red",
        size=20
    ),
)

trace7 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Gram"],
    y=df_cost.MSP[df_cost["Crop"] == "Gram"],
    mode='markers',
    name = "MSP",
    showlegend=False,
    marker=dict(
        color="blue",
        size=20
    ),
)
#-------------------------------------------------------------------------------------------------
trace8 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Groundnut"],
    y=df_cost.Cultivation_Cost[df_cost["Crop"] == "Groundnut"],
    mode='markers',
    name = "Cost of Cultivation",
    showlegend=False,
    marker=dict(
        color="red",
        size=20
    ),
)

trace9 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Groundnut"],
    y=df_cost.MSP[df_cost["Crop"] == "Groundnut"],
    mode='markers',
    name = "MSP",
    showlegend=False,
    marker=dict(
        color="blue",
        size=20
    ),
)

#--------------------------------------------------------------------------------
trace10 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Jowar"],
    y=df_cost.Cultivation_Cost[df_cost["Crop"] == "Jowar"],
    mode='markers',
    name = "Cost of Cultivation",
    showlegend=False,
    marker=dict(
        color="red",
        size=20
    ),
)

trace11 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Jowar"],
    y=df_cost.MSP[df_cost["Crop"] == "Jowar"],
    mode='markers',
    name = "MSP",
    showlegend=False,
    marker=dict(
        color="blue",
        size=20
    ),
)
#-----------------------------------------------------------------------------------
trace12 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Maize"],
    y=df_cost.Cultivation_Cost[df_cost["Crop"] == "Maize"],
    mode='markers',
    name = "Cost of Cultivation",
    showlegend=False,
    marker=dict(
        color="red",
        size=20
    ),
)

trace13 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Maize"],
    y=df_cost.MSP[df_cost["Crop"] == "Maize"],
    mode='markers',
    name = "MSP",
    showlegend=False,
    marker=dict(
        color="blue",
        size=20
    ),
)
#---------------------------------------------------------------------------------
trace14 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Moong"],
    y=df_cost.Cultivation_Cost[df_cost["Crop"] == "Moong"],
    mode='markers',
    name = "Cost of Cultivation",
    showlegend=False,
    marker=dict(
        color="red",
        size=20
    ),
)

trace15 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Moong"],
    y=df_cost.MSP[df_cost["Crop"] == "Moong"],
    mode='markers',
    name = "MSP",
    showlegend=False,
    marker=dict(
        color="blue",
        size=20
    ),
)
#---------------------------------------------------------------------------------------
trace16 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Nigerseed"],
    y=df_cost.Cultivation_Cost[df_cost["Crop"] == "Nigerseed"],
    mode='markers',
    name = "Cost of Cultivation",
    showlegend=False,
    marker=dict(
        color="red",
        size=20
    ),
)

trace17 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Nigerseed"],
    y=df_cost.MSP[df_cost["Crop"] == "Nigerseed"],
    mode='markers',
    name = "MSP",
    showlegend=False,
    marker=dict(
        color="blue",
        size=20
    ),
)
#-----------------------------------------------------------------------------------------------
trace18 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Ragi"],
    y=df_cost.Cultivation_Cost[df_cost["Crop"] == "Ragi"],
    mode='markers',
    name = "Cost of Cultivation",
    showlegend=False,
    marker=dict(
        color="red",
        size=20
    ),
)

trace19 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Ragi"],
    y=df_cost.MSP[df_cost["Crop"] == "Ragi"],
    mode='markers',
    name = "MSP",
    showlegend=False,
    marker=dict(
        color="blue",
        size=20
    ),
)
#-----------------------------------------------------------------------------------
trace20 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Mustard"],
    y=df_cost.Cultivation_Cost[df_cost["Crop"] == "Mustard"],
    mode='markers',
    name = "Cost of Cultivation",
    showlegend=False,
    marker=dict(
        color="red",
        size=20
    ),
)

trace21 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Mustard"],
    y=df_cost.MSP[df_cost["Crop"] == "Mustard"],
    mode='markers',
    name = "MSP",
    showlegend=False,
    marker=dict(
        color="blue",
        size=20
    ),
)
#-------------------------------------------------------------------------------------
trace22 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Rice"],
    y=df_cost.Cultivation_Cost[df_cost["Crop"] == "Rice"],
    mode='markers',
    name = "Cost of Cultivation",
    showlegend=False,
    marker=dict(
        color="red",
        size=20
    ),
)

trace23 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Rice"],
    y=df_cost.MSP[df_cost["Crop"] == "Rice"],
    mode='markers',
    name = "MSP",
    showlegend=False,
    marker=dict(
        color="blue",
        size=20
    ),
)
#-----------------------------------------------------------------------------------------------
trace24 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Safflower"],
    y=df_cost.Cultivation_Cost[df_cost["Crop"] == "Safflower"],
    mode='markers',
    name = "Cost of Cultivation",
    showlegend=False,
    marker=dict(
        color="red",
        size=20
    ),
)

trace25 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Safflower"],
    y=df_cost.MSP[df_cost["Crop"] == "Safflower"],
    mode='markers',
    name = "MSP",
    showlegend=False,
    marker=dict(
        color="blue",
        size=20
    ),
)
#---------------------------------------------------------------------------------------
trace26 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Sesamum"],
    y=df_cost.Cultivation_Cost[df_cost["Crop"] == "Sesamum"],
    mode='markers',
    name = "Cost of Cultivation",
    showlegend=False,
    marker=dict(
        color="red",
        size=20
    ),
)

trace27 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Sesamum"],
    y=df_cost.MSP[df_cost["Crop"] == "Sesamum"],
    mode='markers',
    name = "MSP",
    showlegend=False,
    marker=dict(
        color="blue",
        size=20
    ),
)
#-----------------------------------------------------------------------------
trace28 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Soyabean"],
    y=df_cost.Cultivation_Cost[df_cost["Crop"] == "Soyabean"],
    mode='markers',
    name = "Cost of Cultivation",
    showlegend=False,
    marker=dict(
        color="red",
        size=20
    ),
)

trace29 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Soyabean"],
    y=df_cost.MSP[df_cost["Crop"] == "Soyabean"],
    mode='markers',
    name = "MSP",
    showlegend=False,
    marker=dict(
        color="blue",
        size=20
    ),
)
#------------------------------------------------------------------------
trace30 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Sugarcane"],
    y=df_cost.Cultivation_Cost[df_cost["Crop"] == "Sugarcane"],
    mode='markers',
    name = "Cost of Cultivation",
    showlegend=False,
    marker=dict(
        color="red",
        size=20
    ),
)

trace31 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Sugarcane"],
    y=df_cost.MSP[df_cost["Crop"] == "Sugarcane"],
    mode='markers',
    name = "MSP",
    showlegend=False,
    marker=dict(
        color="blue",
        size=20
    ),
)
#-------------------------------------------------------------------------------
trace32 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Sunflower"],
    y=df_cost.Cultivation_Cost[df_cost["Crop"] == "Sunflower"],
    mode='markers',
    name = "Cost of Cultivation",
    showlegend=False,
    marker=dict(
        color="red",
        size=20
    ),
)

trace33 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Sunflower"],
    y=df_cost.MSP[df_cost["Crop"] == "Sunflower"],
    mode='markers',
    name = "MSP",
    showlegend=False,
    marker=dict(
        color="blue",
        size=20
    ),
)
#---------------------------------------------------------------------------------
trace34 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Urad"],
    y=df_cost.Cultivation_Cost[df_cost["Crop"] == "Urad"],
    mode='markers',
    name = "Cost of Cultivation",
    showlegend=False,
    marker=dict(
        color="red",
        size=20
    ),
)

trace35 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Urad"],
    y=df_cost.MSP[df_cost["Crop"] == "Urad"],
    mode='markers',
    name = "MSP",
    showlegend=False,
    marker=dict(
        color="blue",
        size=20
    ),
)
#---------------------------------------------------------------------------
trace36 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Wheat"],
    y=df_cost.Cultivation_Cost[df_cost["Crop"] == "Wheat"],
    mode='markers',
    name = "Cost of Cultivation",
    showlegend=False,
    marker=dict(
        color="red",
        size=20
    ),
)

trace37 = go.Scatter(
    x=df_cost.Year[df_cost["Crop"] == "Wheat"],
    y=df_cost.MSP[df_cost["Crop"] == "Wheat"],
    mode='markers',
    name = "MSP",
    showlegend=False,
    marker=dict(
        color="blue",
        size=20
    ),
)

fig = tools.make_subplots(rows=10, cols=2, subplot_titles=('Arhar', 'Bajra','Cotton','Gram','Groundnut','Jowar','Maize','Moong','Nigerseed','Ragi','Mustard','Rice','Safflower','Sesamum','Soyabean','Sugarcane','Sunflower','Urad','Wheat'))

fig.append_trace(trace0, 1, 1)
fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)
fig.append_trace(trace3, 1, 2)
fig.append_trace(trace4, 2, 1)
fig.append_trace(trace5, 2, 1)
fig.append_trace(trace6, 2, 2)
fig.append_trace(trace7, 2, 2)
fig.append_trace(trace8, 3, 1)
fig.append_trace(trace9, 3, 1)
fig.append_trace(trace10, 3, 2)
fig.append_trace(trace11, 3, 2)
fig.append_trace(trace12, 4, 1)
fig.append_trace(trace13, 4, 1)
fig.append_trace(trace14, 4, 2)
fig.append_trace(trace15, 4, 2)
fig.append_trace(trace16, 5, 1)
fig.append_trace(trace17, 5, 1)
fig.append_trace(trace18, 5, 2)
fig.append_trace(trace19, 5, 2)
fig.append_trace(trace20, 6, 1)
fig.append_trace(trace21, 6, 1)
fig.append_trace(trace22, 6, 2)
fig.append_trace(trace23, 6, 2)
fig.append_trace(trace24, 7, 1)
fig.append_trace(trace25, 7, 1)
fig.append_trace(trace26, 7, 2)
fig.append_trace(trace27, 7, 2)
fig.append_trace(trace28, 8, 1)
fig.append_trace(trace29, 8, 1)
fig.append_trace(trace30, 8, 2)
fig.append_trace(trace31, 8, 2)
fig.append_trace(trace32, 9, 1)
fig.append_trace(trace33, 9, 1)
fig.append_trace(trace34, 9, 2)
fig.append_trace(trace35, 9, 2)
fig.append_trace(trace36, 10, 1)
fig.append_trace(trace37, 10, 1)

fig['layout'].update(height=4000, width=1300, title='Cultivation Cost and MSP ')
#iplot(fig, filename='make-subplots-multiple-with-titles')
iplot(fig, filename='hide-legend-entry')
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]     [ (1,2) x2,y2 ]
# [ (2,1) x3,y3 ]     [ (2,2) x4,y4 ]
# [ (3,1) x5,y5 ]     [ (3,2) x6,y6 ]
# [ (4,1) x7,y7 ]     [ (4,2) x8,y8 ]
# [ (5,1) x9,y9 ]     [ (5,2) x10,y10 ]
# [ (6,1) x11,y11 ]   [ (6,2) x12,y12 ]
# [ (7,1) x13,y13 ]   [ (7,2) x14,y14 ]
# [ (8,1) x15,y15 ]   [ (8,2) x16,y16 ]
# [ (9,1) x17,y17 ]   [ (9,2) x18,y18 ]
# [ (10,1) x19,y19 ]  [ (10,2) x20,y20 ]
# <div id="69ee34f7-ef60-4d10-8bfb-1c91641b32d0" style="height: 4000px; width: 1300px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("69ee34f7-ef60-4d10-8bfb-1c91641b32d0")) {
# ...

# %%
path6 = "C:/Users/pooja/Desktop/Project/final_Clean_data/Crops/train_data.csv"
df_train = pd.read_csv(path6)

# %%
df_train.describe()
# Out:
#                 pH            N            P            K           OC  \
# count  9915.000000  9915.000000  9915.000000  9915.000000  9915.000000
# mean      7.499429   287.472383    25.139488   455.577850     0.637394
# std       0.471060    96.044070    12.492287    82.996113     0.312248
# min       5.737000   155.208000    10.111000   287.430000     0.417000
# 25%       7.427000   231.718000    14.075000   395.941000     0.476000
# 50%       7.679000   272.108000    22.634000   457.092000     0.522000
# 75%       7.809000   298.268000    31.756000   519.958000     0.602000
# max       8.004000   752.843000    63.784000   602.551000     1.661000
#
#                 Fe     Rainfall  Temperature     Humidity        Min PPH  \
# count  9915.000000  9915.000000  9915.000000  9915.000000    9915.000000
# mean      6.392591   774.922632    25.930564    70.517755   11713.277535
# std       6.042089   728.593270     1.729113    11.949214   18421.081618
# ...

# %%
import plotly
plotly.__version__
# Out:
# '3.7.1'

# %%
path7 = "C:/Users/pooja/Desktop/Project/Map/map.csv"
df_map=pd.read_csv(path7)

# %%
df_map.describe()
# Out:
#         Latitude   Longitude
# count  32.000000   32.000000
# mean   19.430840   76.203679
# std     1.479993    2.151732
# min    16.349219   72.978090
# 25%    18.489012   74.242567
# 50%    19.773530   76.042382
# 75%    20.711492   77.435604
# max    21.462449   80.276733

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import pandas as pd

mapbox_access_token = "pk.eyJ1IjoiYW5kOTkiLCJhIjoiY2p1ZDh6bDIyMGpyeDQzcDlrczZwd2Y2eSJ9.5GjkkVT1kpk7u6ny6Rur3A"

path7 = "C:/Users/pooja/Desktop/Project/Map/map.csv"
df_map = pd.read_csv(path7)


scl = [
    [0.0, 'rgb(242,240,247)'],
    [0.2, 'rgb(218,218,235)'],
]

df_map['text'] = df_map['District'] + '<br>' + \
    'Latitude ' + df_map['Latitude'] + ' Longitude ' + df_map['Longitude']

data = [go.Choropleth(
    colorscale = scl,
    autocolorscale = False,
    locations = df['code'],
    z = df_map['Latitude'].astype(float),
    locationmode = 'ISO-3',
    text = df_map['text'],
    marker = go.choropleth.Marker(
        line = go.choropleth.marker.Line(
            color = 'rgb(255,255,255)',
            width = 2
        )),
  
)]

layout = go.Layout(
    title = go.layout.Title(
        text = 'Maharashtra'
    ),
    geo = go.layout.Geo(
        scope = 'maharashtra',
        projection = go.layout.geo.Projection(type = 'albers usa'),
        showlakes = True,
        lakecolor = 'rgb(255, 255, 255)'),
)

fig = go.Figure(data = data, layout = layout)
py.iplot(fig, filename = 'd3-cloropleth-map')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Latitude'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-78145c332e3b> in <module>
#      15
# ...
