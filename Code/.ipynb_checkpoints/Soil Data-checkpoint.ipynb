\
# 0                                                    NaN               NaN
# 1                                                    NaN               NaN
# 2                                           9.60000 SlAl      0.80000 N
# 3                                           7.00000 N         0.62000 N
# 4                                           7.62000 MAl       0.53000 N
# 5                                           8.30000 MAl       0.86000 N
# 6                                           7.61000 MAl       0.95000 N
# 7                                           7.23000 MAl       0.84000 N
# 8                                           7.62000 MAl       0.87000 N
# 9                                           8.05000 MAl       0.65000 N
# 10                                          8.36000 MAl       0.36000 N
# 11                                          7.63000 MAl       0.49000 N
# 12                                          7.51000 MAl       0.85000 N
# 13                                          7.58000 MAl       0.75000 N
# 14                                          7.51000 MAl       0.68000 N
# 15                                          7.41000 MAl       0.95000 N
# 16                                          7.42000 MAl       0.82000 N
# 17                                          8.64000 SlAl      0.73000 N
# 18                                          7.25000 MAl       0.82000 N
# 19                                          7.63000 MAl       0.87000 N
# 20                                          7.82000 MAl       0.95000 N
# 21                                          7.51000 MAl       0.82000 N
# 22                                          8.29000 MAl       0.35000 N
# 23                                          7.23000 MAl       0.63000 N
# 24                                          7.69000 MAl       0.95000 N
# 25                                          8.46000 MAl       0.84000 N
# 26                                          7.52000 MAl       0.87000 N
# 27                                          8.11000 MAl       0.82000 N
# 28                                          7.36000 MAl       0.66000 N
# 29                                          7.91000 MAl       0.86000 N
# ...                                                  ...               ...
# 13398                                       7.80000 MAl       0.41000 N
# 13399                                       7.60000 MAl       0.30000 N
# 13400                                       7.30000 MAl       0.21000 N
# 13401                                       7.70000 MAl       0.16000 N
# 13402                                       8.10000 MAl       0.22000 N
# 13403                                       7.80000 MAl       0.28000 N
# 13404                                       7.90000 MAl       0.46000 N
# 13405                                       8.00000 MAl       0.20000 N
# 13406                                       7.80000 MAl       0.31000 N
# 13407                                       8.10000 MAl       0.40000 N
# 13408                                       7.90000 MAl       0.25000 N
# 13409                                       7.60000 MAl       0.20000 N
# 13410                                       7.80000 MAl       0.11000 N
# 13411                                       8.00000 MAl       0.43000 N
# 13412                                       7.90000 MAl       0.22000 N
# 13413                                       7.80000 MAl       0.13000 N
# 13414                                       8.00000 MAl       0.41000 N
# 13415                                       7.80000 MAl       0.39000 N
# 13416                                       7.70000 MAl       0.26000 N
# 13417                                       7.70000 MAl       0.18000 N
# 13418                                       8.00000 MAl       0.20000 N
# 13419                                       7.80000 MAl       0.34000 N
# 13420                                       7.60000 MAl       0.19000 N
# 13421                                       8.10000 MAl       0.19000 N
# 13422                                       7.80000 MAl       0.28000 N
# 13423                                       8.00000 MAl       0.46000 N
# 13424                                       7.50000 MAl       0.21000 N
# 13425                                       7.50000 MAl       0.22000 N
# 13426  AS - 0\r\nSrAc - 0\r\nHAc - 0\r\nMAc - 0\r\nSl...             L-  0
# 13427  AS - 16\r\nSrAc - 0\r\nHAc - 2\r\nMAc - 28\r\n...  L-  0\r\nTot - 0
#
#        Unnamed: 4                                                 OC  \
# 0             NaN                                                NaN
# 1             NaN                                                NaN
# 2             NaN                
# ...           ...                                                ...
# 13398         NaN                                                NaN
# 13399         NaN                                                NaN
# 13400         NaN                                                NaN
# 13401         NaN                                                NaN
# 13402         NaN                                                NaN
# 13403         NaN                                                NaN
# 13404         NaN                                                NaN
# 13405         NaN                                                NaN
# 13406         NaN                                                NaN
# 13407         NaN                                                NaN
# 13408         NaN                                                NaN
# 13409         NaN                                                NaN
# 13410         NaN                                                NaN
# 13411         NaN                                                NaN
# 13412         NaN                                                NaN
# 13413         NaN                                                NaN
# 13414         NaN                                                NaN
# 13415         NaN                                                NaN
# 13416         NaN                                                NaN
# 13417         NaN                                                NaN
# 13418         NaN                                                NaN
# 13419         NaN                                                NaN
# 13420         NaN                                                NaN
# 13421         NaN                                                NaN
# 13422         NaN                                                NaN
# 13423         NaN                                                NaN
# 13424         NaN                                                NaN
# 13425         NaN                                                NaN
# 13426         NaN      L - 12\r\nVL - 4\r\nM - 20\r\nH - 1\r\nVH - 0
# 13427         NaN  L - 2713\r\nVL - 949\r\nM - 3493\r\nH - 739\r\...
#
#                                                        P  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                             9.00000 L
# 3                                            20.81000 M
# 4                                            20.56000 M
# 5                                            20.08000 M
# 6                                            19.84000 M
# 7                                            15.24000 M
# 8                                            15.72000 M
# 9                                            21.05000 M
# 10                                           18.14000 M
# 11                                           22.98000 M
# 12                                           15.72000 M
# 13                                           10.40000 M
# 14                                           19.84000 M
# 15                                           21.05000 M
# 16                                           15.48000 M
# 17                                           22.98000 M
# 18                                           15.00000 M
# 19                                           17.42000 M
# 20                                           20.56000 M
# 21                                           14.27000 M
# 22                                           22.98000 M
# 23                                           20.56000 M
# 24                                           12.82000 M
# 25                                           18.14000 M
# 26                                           19.11000 M
# 27                                           21.05000 M
# 28                                           22.50000 M
# 29                                           16.21000 M
# ...                                                  ...
# 13398                                        53.00000 VH
# 13399                                        20.00000 M
# 13400                                        48.00000 VH
# 13401                                        20.00000 M
# 13402                                        29.00000 H
# 13403                                        16.00000 M
# 13404                                        30.00000 H
# 13405                                        19.00000 M
# 13406                                        44.00000 VH
# 13407                                        26.00000 H
# 13408                                        11.00000 M
# 13409                                        39.00000 H
# 13410                                        27.00000 H
# 13411                                         9.00000 L
# 13412                                        46.00000 VH
# 13413                                        20.00000 M
# 13414                                        30.00000 H
# 13415                                        17.00000 M
# 13416                                        33.00000 H
# 13417                                        25.00000 M
# 13418                                        13.00000 M
# 13419                                        68.00000 VH
# 13420                                        21.00000 M
# 13421                                        64.00000 VH
# 13422                                        32.00000 H
# 13423                                        58.00000 VH
# 13424                                        19.00000 M
# 13425                                        26.00000 H
# 13426    L - 1\r\nVL - 0 \r\nM - 33\r\nH - 21\r\nVH - 17
# 13427  L - 1826\r\nVL - 195 \r\nM - 7089\r\nH - 2128\...
#
#                                                        K  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                            81.00000 L
# 3                                           711.42000 VH
# 4                                           607.15000 H
# 5                                           596.08000 H
# 6                                           564.03000 H
# 7                                           510.94000 H
# 8                                           656.54000 H
# 9                                           644.34000 H
# 10                                          589.34000 H
# 11                                          711.42000 VH
# 12                                          607.71000 H
# 13                                          716.24000 VH
# 14                                          660.35000 H
# 15                                          663.04000 H
# 16                                          488.54000 H
# 17                                          730.69000 VH
# 18                                          847.17000 VH
# 19                                          287.06000 M
# 20                                          656.77000 H
# 21                                          843.58000 VH
# 22                                          656.77000 H
# 23                                          731.58000 VH
# 24                                          700.34000 VH
# 25                                         6380.42000 VH
# 26                                          521.02000 H
# 27                                          545.10000 H
# 28                                          731.58000 VH
# 29                                          959.17000 VH
# ...                                                  ...
# 13398                                       224.00000 M
# 13399                                       349.00000 H
# 13400                                       342.00000 H
# 13401                                       471.00000 H
# 13402                                       483.00000 H
# 13403                                       622.00000 H
# 13404                                       690.00000 VH
# 13405                                       205.00000 M
# 13406                                       232.00000 M
# 13407                                       896.00000 VH
# 13408                                       690.00000 VH
# 13409                                       236.00000 M
# 13410                                       393.00000 H
# 13411                                       434.00000 H
# 13412                                       690.00000 VH
# 13413                                       296.00000 M
# 13414                                       735.00000 VH
# 13415                                       616.00000 H
# 13416                                       430.00000 H
# 13417                                       473.00000 H
# 13418                                       350.00000 H
# 13419                                       795.00000 VH
# 13420                                       457.00000 H
# 13421                                       759.00000 VH
# 13422                                       227.00000 M
# 13423                                       353.00000 H
# 13424                                       473.00000 H
# 13425                                       420.00000 H
# 13426    L - 1\r\nVL - 0 \r\nM - 11\r\nH - 20\r\nVH - 40
# 13427  L - 61\r\nVL - 46 \r\nM - 737\r\nH - 5122\r\nV...
#
#                                          S  \
# 0                                      NaN
# 1                                      NaN
# 2                               19.00000 S
# 3                                6.32000 D
# 4                                5.20000 D
# 5                                4.20000 D
# 6                                5.26000 D
# 7                                6.31000 D
# 8                                5.26000 D
# 9                                7.62000 D
# 10                               5.22000 D
# 11                               4.62000 D
# 12                               5.31000 D
# 13                               4.20000 D
# 14                               5.62000 D
# 15                              10.30000 S
# 16                              62.53000 S
# 17                               4.21000 D
# 18                               9.62000 D
# 19                               9.53000 D
# 20                               8.64500 D
# 21                               0.98000 D
# 22                               7.32000 D
# 23                               0.95000 D
# 24                               0.99000 D
# 25                              11.99000 S
# 26                              13.39000 S
# 27                              15.91000 S
# 28                               6.32000 D
# 29                              12.39000 S
# ...                                    ...
# 13398                            3.22000 D
# 13399                            4.19000 D
# 13400                            3.14000 D
# 13401                            2.69000 D
# 13402                            3.81000 D
# 13403                            4.71000 D
# 13404                            2.47000 D
# 13405                            0.94000 D
# 13406                            5.69000 D
# 13407                            4.11000 D
# 13408                            3.07000 D
# 13409                            2.69000 D
# 13410                            2.47000 D
# 13411                            2.92000 D
# 13412                            3.14000 D
# 13413                            3.14000 D
# 13414                            3.22000 D
# 13415                            3.81000 D
# 13416                            1.94000 D
# 13417                            3.07000 D
# 13418                            4.90000 D
# 13419                            1.27000 D
# 13420                            1.89000 D
# 13421                            5.76000 D
# 13422                            4.11000 D
# 13423                            1.57000 D
# 13424                            1.64000 D
# 13425                            3.14000 D
# 13426                     S - 19\r\nD - 53
# 13427  S - 1242\r\nD - 9538\r\nTot - 10780
#
#                                                       Zn  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                              0.32000 D
# 3                                              0.96000 S
# 4                                              0.85000 S
# 5                                              0.87000 S
# 6                                              0.84000 S
# 7                                              0.75000 S
# 8                                              0.52000 D
# 9                                              0.85000 S
# 10                                             0.65000 S
# 11                                             0.53000 D
# 12                                             0.95000 S
# 13                                             0.84000 S
# 14                                             0.87000 S
# 15                                             0.85000 S
# 16                                             0.98000 S
# 17                                             0.85000 S
# 18                                             0.63000 S
# 19                                             0.95000 S
# 20                                             0.82000 S
# 21                                             0.62000 S
# 22                                             0.85000 S
# 23                                             0.64000 S
# 24                                             0.72000 S
# 25                                             0.53000 D
# 26                                             0.55000 D
# 27                                             0.93000 S
# 28                                             0.65000 S
# 29                                             0.84000 S
# ...                                                  ...
# 13398                                          0.54000 D
# 13399                                          0.58000 D
# 13400                                          0.50000 D
# 13401                                          0.49000 D
# 13402                                          0.46000 D
# 13403                                          0.54000 D
# 13404                                          0.50000 D
# 13405                                          0.44000 D
# 13406                                          0.62000 S
# 13407                                          0.32000 D
# 13408                                          0.66000 S
# 13409                                          0.58000 D
# 13410                                          0.44000 D
# 13411                                          0.17000 D
# 13412                                          0.49000 D
# 13413                                          0.49000 D
# 13414                                          0.46000 D
# 13415                                          0.38000 D
# 13416                                          0.68000 S
# 13417                                          0.49000 D
# 13418                                          0.52000 D
# 13419                                          0.48000 D
# 13420                                          0.42000 D
# 13421                                          0.32000 D
# 13422                                          0.58000 D
# 13423                                          0.46000 D
# 13424                                          0.46000 D
# 13425                                          0.65000 S
# 13426                                   S - 40\r\nD - 32
# 13427  S - 4637\r\nD - 8455\r\nTot - 13092\r\n\r\n  \...
#
#                                         Fe  Unnamed: 13  \
# 0                                      NaN          NaN
# 1                                      NaN          NaN
# 2                                1.74000 D          NaN
# 3                                3.62000 D          NaN
# 4                                5.26000 S          NaN
# 5                                5.31000 S          NaN
# 6                                4.22000 D          NaN
# 7                                4.01000 D          NaN
# 8                                4.32000 D          NaN
# 9                                5.26000 S          NaN
# 10                               5.31000 S          NaN
# 11                               5.62000 S          NaN
# 12                               5.62000 S          NaN
# 13                               5.31000 S          NaN
# 14                               4.26000 D          NaN
# 15                               6.52000 S          NaN
# 16                               5.31000 S          NaN
# 17                               4.26000 D          NaN
# 18                               5.60000 S          NaN
# 19                               6.32000 S          NaN
# 20                               5.32000 S          NaN
# 21                               6.52000 S          NaN
# 22                              76.32000 S          NaN
# 23                               5.32000 S          NaN
# 24                               2.31000 D          NaN
# 25                               5.62000 S          NaN
# 26                               4.22000 D          NaN
# 27                               5.26000 S          NaN
# 28                               4.55000 S          NaN
# 29                               5.21000 S          NaN
# ...                                    ...          ...
# 13398                            4.18000 D          NaN
# 13399                            4.24000 D          NaN
# 13400                            4.49000 D          NaN
# 13401                            4.52000 S          NaN
# 13402                            4.50000 D          NaN
# 13403                            4.48000 D          NaN
# 13404                            4.18000 D          NaN
# 13405                            4.29000 D          NaN
# 13406                            4.50000 D          NaN
# 13407                            4.26000 D          NaN
# 13408                            4.51000 S          NaN
# 13409                            4.42000 D          NaN
# 13410                            4.19000 D          NaN
# 13411                            4.55000 S          NaN
# 13412                            4.08000 D          NaN
# 13413                            4.08000 D          NaN
# 13414                            4.52000 S          NaN
# 13415                            4.08000 D          NaN
# 13416                            4.59000 S          NaN
# 13417                            4.22000 D          NaN
# 13418                            4.19000 D          NaN
# 13419                            4.51000 S          NaN
# 13420                            4.26000 D          NaN
# 13421                            4.29000 D          NaN
# 13422                            4.50000 D          NaN
# 13423                            4.48000 D          NaN
# 13424                            4.48000 D          NaN
# 13425                            4.48000 D          NaN
# 13426                 S - 45\r\nD - 27\r\n          NaN
# 13427  S - 4288\r\nD - 8799\r\nTot - 13087          NaN
#
#                                         Cu  \
# 0                                      NaN
# 1                                      NaN
# 2                                0.13000 D
# 3                                1.26000 S
# 4                                3.20000 S
# 5                                2.61000 S
# 6                                5.31000 S
# 7                                4.21000 S
# 8                                4.02000 S
# 9                                4.06000 S
# 10                               3.21000 S
# 11                               2.65000 S
# 12                               3.55000 S
# 13                               3.21000 S
# 14                               3.66000 S
# 15                               5.21000 S
# 16                               2.31000 S
# 17                               2.65000 S
# 18                               4.20000 S
# 19                               4.51000 S
# 20                               4.25000 S
# 21                               5.31000 S
# 22                               6.32000 S
# 23                               2.30000 S
# 24                               2.31000 S
# 25                               4.21000 S
# 26                               2.04000 S
# 27                               4.29000 S
# 28                               0.98000 S
# 29                               1.99000 S
# ...                                    ...
# 13398                            2.88000 S
# 13399                            2.80000 S
# 13400                            2.49000 S
# 13401                            2.40000 S
# 13402                            2.58000 S
# 13403                            2.64000 S
# 13404                            2.08000 S
# 13405                            2.44000 S
# 13406                            2.49000 S
# 13407                            2.34000 S
# 13408                            2.52000 S
# 13409                            2.46000 S
# 13410                            2.32000 S
# 13411                            2.39000 S
# 13412                            2.16000 S
# 13413                            2.16000 S
# 13414                            2.44000 S
# 13415                            2.37000 S
# 13416                            2.40000 S
# 13417                            2.78000 S
# 13418                            2.06000 S
# 13419                            2.44000 S
# 13420                            2.19000 S
# 13421                            2.28000 S
# 13422                            2.12000 S
# 13423                            2.48000 S
# 13424                            2.48000 S
# 13425                            2.48000 S
# 13426                 S - 72 \r\nD - 0\r\n
# 13427  S - 13017 \r\nD - 35\r\nTot - 13052
#
#                                         Mn  \
# 0                                      NaN
# 1                                      NaN
# 2                                2.50000 S
# 3                               16.32000 S
# 4                               18.52000 S
# 5                               21.30000 S
# 6                               22.30000 S
# 7                               17.26000 S
# 8                               22.36000 S
# 9                               18.00000 S
# 10                              19.65000 S
# 11                              19.81000 S
# 12                              18.63000 S
# 13                              16.58000 S
# 14                              20.65000 S
# 15                              14.25000 S
# 16                              18.43000 S
# 17                              19.66000 S
# 18                              17.23000 S
# 19                              23.96000 S
# 20                              16.32000 S
# 21                              22.79000 S
# 22                              19.81000 S
# 23                              23.76000 S
# 24                              23.42000 S
# 25                              20.00000 S
# 26                              19.76000 S
# 27                              19.96000 S
# 28                              16.38000 S
# 29                              24.30000 S
# ...                                    ...
# 13398                           16.70000 S
# 13399                           15.94000 S
# 13400                           10.94000 S
# 13401                            9.84000 S
# 13402                           10.92000 S
# 13403                           12.38000 S
# 13404                           12.98000 S
# 13405                           14.08000 S
# 13406                           12.62000 S
# 13407                           12.94000 S
# 13408                           14.91000 S
# 13409                           12.90000 S
# 13410                           11.49000 S
# 13411                           12.48200 S
# 13412                           10.96000 S
# 13413                           10.96000 S
# 13414                           10.90000 S
# 13415                            9.92000 S
# 13416                            8.84000 S
# 13417                           10.78000 S
# 13418                           12.63000 S
# 13419                            9.42000 S
# 13420                            8.74000 S
# 13421                           12.96000 S
# 13422                            9.48000 S
# 13423                            9.94000 S
# 13424                            9.94000 S
# 13425                            9.94000 S
# 13426                  S - 71\r\nD - 0\r\n
# 13427  S - 12905\r\nD - 117\r\nTot - 13022
#
#                                          B
# 0                                      NaN
# 1                                      NaN
# 2                                4.57000 S
# 3                                1.32000 S
# 4                                1.52000 S
# 5                                1.62000 S
# 6                                0.95000 S
# 7                                0.98000 S
# 8                                0.97000 S
# 9                                1.65000 S
# 10                               1.45000 S
# 11                               2.02000 S
# 12                               1.63000 S
# 13                               0.86000 S
# 14                               1.46000 S
# 15                               1.75000 S
# 16                               1.56000 S
# 17                               0.29000 D
# 18                               1.44000 S
# 19                               0.89000 S
# 20                               0.52000 S
# 21                               1.42000 S
# 22                               1.67000 S
# 23                               1.44000 S
# 24                               1.23000 S
# 25                               0.87000 S
# 26                               0.63000 S
# 27                               0.36000 D
# 28                               0.86000 S
# 29                               1.46000 S
# ...                                    ...
# 13398                            0.03800 D
# 13399                            0.03600 D
# 13400                            0.01500 D
# 13401                            0.01500 D
# 13402                            0.01800 D
# 13403                            0.01800 D
# 13404                            0.01800 D
# 13405                            0.01500 D
# 13406                            0.02100 D
# 13407                            0.21600 D
# 13408                            0.01800 D
# 13409                            0.02100 D
# 13410                            0.02100 D
# 13411                            0.01100 D
# 13412                            0.02100 D
# 13413                            0.02100 D
# 13414                            0.01500 D
# 13415                            0.03300 D
# 13416                            0.01800 D
# 13417                            0.01800 D
# 13418                            0.03800 D
# 13419                            0.02400 D
# 13420                            0.01800 D
# 13421                            0.03300 D
# 13422                            0.02100 D
# 13423                            0.03800 D
# 13424                            0.03800 D
# 13425                            0.03800 D
# 13426                 S - 28\r\nD - 44\r\n
# 13427  S - 4536\r\nD - 6235\r\nTot - 10771
#
# [13428 rows x 17 columns]

# %%
df_csv
# Out:
#       Sr.No.                 Sample No.  \
# 0          1        Block/Mandal: Akola
# 1        NaN              Village: AGAR
# 2          1  AP592634/2017-18/72552371
# 3          2  MH529995/2016-17/26261777
# 4          3  MH529995/2016-17/26262058
# 5          4  MH529995/2016-17/26262410
# 6          5  MH529995/2016-17/26262981
# 7          6  MH529995/2016-17/26263498
# 8          7  MH529995/2016-17/26264212
# 9          8  MH529995/2016-17/26264673
# 10         9  MH529995/2016-17/26265262
# 11        10  MH529995/2016-17/26265967
# 12        11  MH529995/2016-17/26266441
# 13        12  MH529995/2016-17/26266941
# 14        13  MH529995/2016-17/26267764
# 15        14  MH529995/2016-17/26268477
# 16        15  MH529995/2016-17/26317768
# 17        16  MH529995/2016-17/26318722
# 18        17  MH529995/2016-17/26319803
# 19        18  MH529995/2016-17/26320811
# 13399                                       7.60000 MAl       0.30000 N
# 13400                                       7.30000 MAl       0.21000 N
# 13401                                       7.70000 MAl       0.16000 N
# 13402                                       8.10000 MAl       0.22000 N
# 13403                                       7.80000 MAl       0.28000 N
# 13404                                       7.90000 MAl       0.46000 N
# 13405                                       8.00000 MAl       0.20000 N
# 13406                                       7.80000 MAl       0.31000 N
# 13407                                       8.10000 MAl       0.40000 N
# 13408                                       7.90000 MAl       0.25000 N
# 13409                                       7.60000 MAl       0.20000 N
# 13410                                       7.80000 MAl       0.11000 N
# 13411                                       8.00000 MAl       0.43000 N
# 13412                                       7.90000 MAl       0.22000 N
# 13413                                       7.80000 MAl       0.13000 N
# 13414                                       8.00000 MAl       0.41000 N
# 13415                                       7.80000 MAl       0.39000 N
# 13416                                       7.70000 MAl       0.26000 N
# 13417                                       7.70000 MAl       0.18000 N
# 13418                                       8.00000 MAl       0.20000 N
# 13419                                       7.80000 MAl       0.34000 N
# 13420                                       7.60000 MAl       0.19000 N
# 13421                                       8.10000 MAl       0.19000 N
# 13422                                       7.80000 MAl       0.28000 N
# 13423                                       8.00000 MAl       0.46000 N
# 13424                                       7.50000 MAl       0.21000 N
# 13425                                       7.50000 MAl       0.22000 N
# 13426  AS - 0\r\nSrAc - 0\r\nHAc - 0\r\nMAc - 0\r\nSl...             L-  0
# 13427  AS - 16\r\nSrAc - 0\r\nHAc - 2\r\nMAc - 28\r\n...  L-  0\r\nTot - 0
#
#                                                       OC  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                             0.60000 M
# 3                                             0.99000 H
# 4                                             0.78000 H
# 5                                             0.84000 H
# 6                                             0.93000 H
# 7                                             0.53000 M
# 8                                             1.08000 VH
# 9                                             0.81000 H
# 10                                            0.89000 H
# 11                                            0.75000 M
# 12                                            0.77000 H
# 13                                            0.74000 M
# 14                                            0.75000 M
# 15                                            0.62000 M
# 16                                            0.60000 M
# 17                                            0.65000 M
# 18                                            0.78000 H
# 19                                            0.68000 M
# 20                                            0.68000 M
# 21                                            0.84000 H
# 22                                            0.83000 H
# 23                                            0.99000 H
# 24                                            0.65000 M
# 25                                            0.48000 L
# 26                                            0.65000 M
# 27                                            0.68000 M
# 28                                            0.78000 H
# 29                                            0.78000 H
# ...                                                  ...
# 13398                                         0.33000 L
# 13399                                         0.22000 VL
# 13400                                         0.37000 L
# 13401                                         0.21000 VL
# 13402                                         0.42000 L
# 13403                                         0.24000 VL
# 13404                                         0.36000 L
# 13405                                         0.38000 L
# 13406                                         0.28000 L
# 13407                                         0.34000 L
# 13408                                         0.14000 VL
# 13409                                         0.20000 VL
# 13410                                         0.23000 VL
# 13411                                         0.23000 VL
# 13412                                         0.27000 L
# 13413                                         0.22000 VL
# 13414                                         0.41000 L
# 13415                                         0.28000 L
# 13416                                         0.27000 L
# 13417                                         0.30000 L
# 13418                                         0.22000 VL
# 13419                                         0.23000 VL
# 13420                                         0.41000 L
# 13421                                         0.64000 M
# 13422                                         0.41000 L
# 13423                                         0.19000 VL
# 13424                                         0.32000 L
# 13425                                         0.21000 VL
# 13426    L - 41\r\nVL - 19 \r\nM - 10\r\nH - 2\r\nVH - 0
# 13427  L - 5939\r\nVL - 2353 \r\nM - 3050\r\nH - 1113...
#
#                                                        N  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                           191.00000 L
# 3                                           693.00000 H
# 4                                           546.00000 M
# 5                                           588.00000 H
# 6                                           651.00000 H
# 7                                           367.50000 M
# 8                                           756.00000 VH
# 9                                           567.00000 H
# 10                                          619.50000 H
# 11                                          525.00000 M
# 12                                          535.50000 M
# 13                                          515.60000 M
# 14                                          525.00000 M
# 15                                          430.50000 M
# 16                                          420.00000 M
# 17                                          451.50000 M
# 18                                          546.00000 M
# 19                                          472.50000 M
# 20                                          472.50000 M
# 21                                          588.00000 H
# 22                                          577.50000 H
# 23                                          693.00000 H
# 24                                          451.50000 M
# 25                                          336.00000 M
# 26                                          451.50000 M
# 27                                          472.50000 M
# 28                                          546.00000 M
# 29                                          546.00000 M
# ...                                                  ...
# 13398                                                NaN
# 13399                                                NaN
# 13400                                                NaN
# 13401                                                NaN
# 13402                                                NaN
# 13403                                                NaN
# 13404                                                NaN
# 13405                                                NaN
# 13406                                                NaN
# 13407                                                NaN
# 13408                                                NaN
# 13409                                                NaN
# 13410                                                NaN
# 13411                                                NaN
# 13412                                                NaN
# 13413                                                NaN
# 13414                                                NaN
# 13415                                                NaN
# 13416                                                NaN
# 13417                                                NaN
# 13418                                                NaN
# 13419                                                NaN
# 13420                                                NaN
# 13421                                                NaN
# 13422                                                NaN
# 13423                                                NaN
# 13424                                                NaN
# 13425                                                NaN
# 13426      L - 12\r\nVL - 4\r\nM - 20\r\nH - 1\r\nVH - 0
# 13427  L - 2713\r\nVL - 949\r\nM - 3493\r\nH - 739\r\...
#
#                                                        P  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                             9.00000 L
# 3                                            20.81000 M
# 4                                            20.56000 M
# 5                                            20.08000 M
# 6                                            19.84000 M
# 7                                            15.24000 M
# 8                                            15.72000 M
# 9                                            21.05000 M
# 10                                           18.14000 M
# 11                                           22.98000 M
# 12                                           15.72000 M
# 13                                           10.40000 M
# 14                                           19.84000 M
# 15                                           21.05000 M
# 16                                           15.48000 M
# 17                                           22.98000 M
# 18                                           15.00000 M
# 19                                           17.42000 M
# 20                                           20.56000 M
# 21                                           14.27000 M
# 22                                           22.98000 M
# 23                                           20.56000 M
# 24                                           12.82000 M
# 25                                           18.14000 M
# 26                                           19.11000 M
# 27                                           21.05000 M
# 28                                           22.50000 M
# 29                                           16.21000 M
# ...                                                  ...
# 13398                                        53.00000 VH
# 13399                                        20.00000 M
# 13400                                        48.00000 VH
# 13401                                        20.00000 M
# 13402                                        29.00000 H
# 13403                                        16.00000 M
# 13404                                        30.00000 H
# 13405                                        19.00000 M
# 13406                                        44.00000 VH
# 13407                                        26.00000 H
# 13408                                        11.00000 M
# 13409                                        39.00000 H
# 13410                                        27.00000 H
# 13411                                         9.00000 L
# 13412                                        46.00000 VH
# 13413                                        20.00000 M
# 13414                                        30.00000 H
# 13415                                        17.00000 M
# 13416                                        33.00000 H
# 13417                                        25.00000 M
# 13418                                        13.00000 M
# 13419                                        68.00000 VH
# 13420                                        21.00000 M
# 13421                                        64.00000 VH
# 13422                                        32.00000 H
# 13423                                        58.00000 VH
# 13424                                        19.00000 M
# 13425                                        26.00000 H
# 13426    L - 1\r\nVL - 0 \r\nM - 33\r\nH - 21\r\nVH - 17
# 13427  L - 1826\r\nVL - 195 \r\nM - 7089\r\nH - 2128\...
#
#                                                        K  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                            81.00000 L
# 3                                           711.42000 VH
# 4                                           607.15000 H
# 5                                           596.08000 H
# 6                                           564.03000 H
# 7                                           510.94000 H
# 8                                           656.54000 H
# 9                                           644.34000 H
# 10                                          589.34000 H
# 11                                          711.42000 VH
# 12                                          607.71000 H
# 13                                          716.24000 VH
# 14                                          660.35000 H
# 15                                          663.04000 H
# 16                                          488.54000 H
# 17                                          730.69000 VH
# 18                                          847.17000 VH
# 19                                          287.06000 M
# 20                                          656.77000 H
# 21                                          843.58000 VH
# 22                                          656.77000 H
# 23                                          731.58000 VH
# 24                                          700.34000 VH
# 25                                         6380.42000 VH
# 26                                          521.02000 H
# 27                                          545.10000 H
# 28                                          731.58000 VH
# 29                                          959.17000 VH
# ...                                                  ...
# 13398                                       224.00000 M
# 13399                                       349.00000 H
# 13400                                       342.00000 H
# 13401                                       471.00000 H
# 13402                                       483.00000 H
# 13403                                       622.00000 H
# 13404                                       690.00000 VH
# 13405                                       205.00000 M
# 13406                                       232.00000 M
# 13407                                       896.00000 VH
# 13408                                       690.00000 VH
# 13409                                       236.00000 M
# 13410                                       393.00000 H
# 13411                                       434.00000 H
# 13412                                       690.00000 VH
# 13413                                       296.00000 M
# 13414                                       735.00000 VH
# 13415                                       616.00000 H
# 13416                                       430.00000 H
# 13417                                       473.00000 H
# 13418                                       350.00000 H
# 13419                                       795.00000 VH
# 13420                                       457.00000 H
# 13421                                       759.00000 VH
# 13422                                       227.00000 M
# 13423                                       353.00000 H
# 13424                                       473.00000 H
# 13425                                       420.00000 H
# 13426    L - 1\r\nVL - 0 \r\nM - 11\r\nH - 20\r\nVH - 40
# 13427  L - 61\r\nVL - 46 \r\nM - 737\r\nH - 5122\r\nV...
#
#                                          S  \
# 0                                      NaN
# 1                                      NaN
# 2                               19.00000 S
# 3                                6.32000 D
# 4                                5.20000 D
# 5                                4.20000 D
# 6                                5.26000 D
# 7                                6.31000 D
# 8                                5.26000 D
# 9                                7.62000 D
# 10                               5.22000 D
# 11                               4.62000 D
# 12                               5.31000 D
# 13                               4.20000 D
# 14                               5.62000 D
# 15                              10.30000 S
# 16                              62.53000 S
# 17                               4.21000 D
# 18                               9.62000 D
# 19                               9.53000 D
# 20                               8.64500 D
# 21                               0.98000 D
# 22                               7.32000 D
# 23                               0.95000 D
# 24                               0.99000 D
# 25                              11.99000 S
# 26                              13.39000 S
# 27                              15.91000 S
# 28                               6.32000 D
# 29                              12.39000 S
# ...                                    ...
# 13398                            3.22000 D
# 13399                            4.19000 D
# 13400                            3.14000 D
# 13401                            2.69000 D
# 13402                            3.81000 D
# 13403                            4.71000 D
# 13404                            2.47000 D
# 13405                            0.94000 D
# 13406                            5.69000 D
# 13407                            4.11000 D
# 13408                            3.07000 D
# 13409                            2.69000 D
# 13410                            2.47000 D
# 13411                            2.92000 D
# 13412                            3.14000 D
# 13413                            3.14000 D
# 13414                            3.22000 D
# 13415                            3.81000 D
# 13416                            1.94000 D
# 13417                            3.07000 D
# 13418                            4.90000 D
# 13419                            1.27000 D
# 13420                            1.89000 D
# 13421                            5.76000 D
# 13422                            4.11000 D
# 13423                            1.57000 D
# 13424                            1.64000 D
# 13425                            3.14000 D
# 13426                     S - 19\r\nD - 53
# 13427  S - 1242\r\nD - 9538\r\nTot - 10780
#
#                                                       Zn  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                              0.32000 D
# 3                                              0.96000 S
# 4                                              0.85000 S
# 5                                              0.87000 S
# 6                                              0.84000 S
# 7                                              0.75000 S
# 8                                              0.52000 D
# 9                                              0.85000 S
# 10                                             0.65000 S
# 11                                             0.53000 D
# 12                                             0.95000 S
# 13                                             0.84000 S
# 14                                             0.87000 S
# 15                                             0.85000 S
# 16                                             0.98000 S
# 17                                             0.85000 S
# 18                                             0.63000 S
# 19                                             0.95000 S
# 20                                             0.82000 S
# 21                                             0.62000 S
# 22                                             0.85000 S
# 23                                             0.64000 S
# 24                                             0.72000 S
# 25                                             0.53000 D
# 26                                             0.55000 D
# 27                                             0.93000 S
# 28                                             0.65000 S
# 29                                             0.84000 S
# ...                                                  ...
# 13398                                          0.54000 D
# 13399                                          0.58000 D
# 13400                                          0.50000 D
# 13401                                          0.49000 D
# 13402                                          0.46000 D
# 13403                                          0.54000 D
# 13404                                          0.50000 D
# 13405                                          0.44000 D
# 13406                                          0.62000 S
# 13407                                          0.32000 D
# 13408                                          0.66000 S
# 13409                                          0.58000 D
# 13410                                          0.44000 D
# 13411                                          0.17000 D
# 13412                                          0.49000 D
# 13413                                          0.49000 D
# 13414                                          0.46000 D
# 13415                                          0.38000 D
# 13416                                          0.68000 S
# 13417                                          0.49000 D
# 13418                                          0.52000 D
# 13419                                          0.48000 D
# 13420                                          0.42000 D
# 13421                                          0.32000 D
# 13422                                          0.58000 D
# 13423                                          0.46000 D
# 13424                                          0.46000 D
# 13425                                          0.65000 S
# 13426                                   S - 40\r\nD - 32
# 13427  S - 4637\r\nD - 8455\r\nTot - 13092\r\n\r\n  \...
#
#                                         Fe  \
# 0                                      NaN
# 1                                      NaN
# 2                                1.74000 D
# 3                                3.62000 D
# 4                                5.26000 S
# 5                                5.31000 S
# 6                                4.22000 D
# 7                                4.01000 D
# 8                                4.32000 D
# 9                                5.26000 S
# 10                               5.31000 S
# 11                               5.62000 S
# 12                               5.62000 S
# 13                               5.31000 S
# 14                               4.26000 D
# 15                               6.52000 S
# 16                               5.31000 S
# 17                               4.26000 D
# 18                               5.60000 S
# 19                               6.32000 S
# 20                               5.32000 S
# 21                               6.52000 S
# 22                              76.32000 S
# 23                               5.32000 S
# 24                               2.31000 D
# 25                               5.62000 S
# 26                               4.22000 D
# 27                               5.26000 S
# 28                               4.55000 S
# 29                               5.21000 S
# ...                                    ...
# 13398                            4.18000 D
# 13399                            4.24000 D
# 13400                            4.49000 D
# 13401                            4.52000 S
# 13402                            4.50000 D
# 13403                            4.48000 D
# 13404                            4.18000 D
# 13405                            4.29000 D
# 13406                            4.50000 D
# 13407                            4.26000 D
# 13408                            4.51000 S
# 13409                            4.42000 D
# 13410                            4.19000 D
# 13411                            4.55000 S
# 13412                            4.08000 D
# 13413                            4.08000 D
# 13414                            4.52000 S
# 13415                            4.08000 D
# 13416                            4.59000 S
# 13417                            4.22000 D
# 13418                            4.19000 D
# 13419                            4.51000 S
# 13420                            4.26000 D
# 13421                            4.29000 D
# 13422                            4.50000 D
# 13423                            4.48000 D
# 13424                            4.48000 D
# 13425                            4.48000 D
# 13426                 S - 45\r\nD - 27\r\n
# 13427  S - 4288\r\nD - 8799\r\nTot - 13087
#
#                                         Cu  \
# 0                                      NaN
# 1                                      NaN
# 2                                0.13000 D
# 3                                1.26000 S
# 4                                3.20000 S
# 5                                2.61000 S
# 6                                5.31000 S
# 7                                4.21000 S
# 8                                4.02000 S
# 9                                4.06000 S
# 10                               3.21000 S
# 11                               2.65000 S
# 12                               3.55000 S
# 13                               3.21000 S
# 14                               3.66000 S
# 15                               5.21000 S
# 16                               2.31000 S
# 17                               2.65000 S
# 18                               4.20000 S
# 19                               4.51000 S
# 20                               4.25000 S
# 21                               5.31000 S
# 22                               6.32000 S
# 23                               2.30000 S
# 24                               2.31000 S
# 25                               4.21000 S
# 26                               2.04000 S
# 27                               4.29000 S
# 28                               0.98000 S
# 29                               1.99000 S
# ...                                    ...
# 13398                            2.88000 S
# 13399                            2.80000 S
# 13400                            2.49000 S
# 13401                            2.40000 S
# 13402                            2.58000 S
# 13403                            2.64000 S
# 13404                            2.08000 S
# 13405                            2.44000 S
# 13406                            2.49000 S
# 13407                            2.34000 S
# 13408                            2.52000 S
# 13409                            2.46000 S
# 13410                            2.32000 S
# 13411                            2.39000 S
# 13412                            2.16000 S
# 13413                            2.16000 S
# 13414                            2.44000 S
# 13415                            2.37000 S
# 13416                            2.40000 S
# 13417                            2.78000 S
# 13418                            2.06000 S
# 13419                            2.44000 S
# 13420                            2.19000 S
# 13421                            2.28000 S
# 13422                            2.12000 S
# 13423                            2.48000 S
# 13424                            2.48000 S
# 13425                            2.48000 S
# 13426                 S - 72 \r\nD - 0\r\n
# 13427  S - 13017 \r\nD - 35\r\nTot - 13052
#
#                                         Mn  \
# 0                                      NaN
# 1                                      NaN
# 2                                2.50000 S
# 3                               16.32000 S
# 4                               18.52000 S
# 5                               21.30000 S
# 6                               22.30000 S
# 7                               17.26000 S
# 8                               22.36000 S
# 9                               18.00000 S
# 10                              19.65000 S
# 11                              19.81000 S
# 12                              18.63000 S
# 13                              16.58000 S
# 14                              20.65000 S
# 15                              14.25000 S
# 16                              18.43000 S
# 17                              19.66000 S
# 18                              17.23000 S
# 19                              23.96000 S
# 20                              16.32000 S
# 21                              22.79000 S
# 22                              19.81000 S
# 23                              23.76000 S
# 24                              23.42000 S
# 25                              20.00000 S
# 26                              19.76000 S
# 27                              19.96000 S
# 28                              16.38000 S
# 29                              24.30000 S
# ...                                    ...
# 13398                           16.70000 S
# 13399                           15.94000 S
# 13400                           10.94000 S
# 13401                            9.84000 S
# 13402                           10.92000 S
# 13403                           12.38000 S
# 13404                           12.98000 S
# 13405                           14.08000 S
# 13406                           12.62000 S
# 13407                           12.94000 S
# 13408                           14.91000 S
# 13409                           12.90000 S
# 13410                           11.49000 S
# 13411                           12.48200 S
# 13412                           10.96000 S
# 13413                           10.96000 S
# 13414                           10.90000 S
# 13415                            9.92000 S
# 13416                            8.84000 S
# 13417                           10.78000 S
# 13418                           12.63000 S
# 13419                            9.42000 S
# 13420                            8.74000 S
# 13421                           12.96000 S
# 13422                            9.48000 S
# 13423                            9.94000 S
# 13424                            9.94000 S
# 13425                            9.94000 S
# 13426                  S - 71\r\nD - 0\r\n
# 13427  S - 12905\r\nD - 117\r\nTot - 13022
#
#                                          B
# 0                                      NaN
# 1                                      NaN
# 2                                4.57000 S
# 3                                1.32000 S
# 4                                1.52000 S
# 5                                1.62000 S
# 6                                0.95000 S
# 7                                0.98000 S
# 8                                0.97000 S
# 9                                1.65000 S
# 10                               1.45000 S
# 11                               2.02000 S
# 12                               1.63000 S
# 13                               0.86000 S
# 14                               1.46000 S
# 15                               1.75000 S
# 16                               1.56000 S
# 17                               0.29000 D
# 18                               1.44000 S
# 19                               0.89000 S
# 20                               0.52000 S
# 21                               1.42000 S
# 22                               1.67000 S
# 23                               1.44000 S
# 24                               1.23000 S
# 25                               0.87000 S
# 26                               0.63000 S
# 27                               0.36000 D
# 28                               0.86000 S
# 29                               1.46000 S
# ...                                    ...
# 13398                            0.03800 D
# 13399                            0.03600 D
# 13400                            0.01500 D
# 13401                            0.01500 D
# 13402                            0.01800 D
# 13403                            0.01800 D
# 13404                            0.01800 D
# 13405                            0.01500 D
# 13406                            0.02100 D
# 13407                            0.21600 D
# 13408                            0.01800 D
# 13409                            0.02100 D
# 13410                            0.02100 D
# 13411                            0.01100 D
# 13412                            0.02100 D
# 13413                            0.02100 D
# 13414                            0.01500 D
# 13415                            0.03300 D
# 13416                            0.01800 D
# 13417                            0.01800 D
# 13418                            0.03800 D
# 13419                            0.02400 D
# 13420                            0.01800 D
# 13421                            0.03300 D
# 13422                            0.02100 D
# 13423                            0.03800 D
# 13424                            0.03800 D
# 13425                            0.03800 D
# 13426                 S - 28\r\nD - 44\r\n
# 13427  S - 4536\r\nD - 6235\r\nTot - 10771
#
# [13428 rows x 14 columns]

# %%
# Out:
# C:\Users\amogh\Anaconda3\lib\site-packages\pandas\core\generic.py:7772: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors, try_cast=try_cast)

# %%
df_csv
# Out:
#       Sr.No.                 Sample No.            pH            EC  \
# 1        NaN              Village: AGAR           NaN           NaN
# 3          2  MH529995/2016-17/26261777  7.00000 N     0.62000 N
# 4          3  MH529995/2016-17/26262058  7.62000 MAl   0.53000 N
# 5          4  MH529995/2016-17/26262410  8.30000 MAl   0.86000 N
# 6          5  MH529995/2016-17/26262981  7.61000 MAl   0.95000 N
# 7          6  MH529995/2016-17/26263498  7.23000 MAl   0.84000 N
# 8          7  MH529995/2016-17/26264212  7.62000 MAl   0.87000 N
# 9          8  MH529995/2016-17/26264673  8.05000 MAl   0.65000 N
# 31     0.98000 H   682.50000 H   12.34000 M    789.71000 VH  14.51000 S
# ...           ...           ...          ...            ...         ...
# 13396  0.30000 L            NaN  62.00000 VH   217.00000 M    3.14000 D
# 13397  0.18000 VL           NaN  17.00000 M    217.00000 M    3.89000 D
# 13398  0.33000 L            NaN  53.00000 VH   224.00000 M    3.22000 D
# 13399  0.22000 VL           NaN  20.00000 M    349.00000 H    4.19000 D
# 13400  0.37000 L            NaN  48.00000 VH   342.00000 H    3.14000 D
# 13401  0.21000 VL           NaN  20.00000 M    471.00000 H    2.69000 D
# 13402  0.42000 L            NaN  29.00000 H    483.00000 H    3.81000 D
# 13403  0.24000 VL           NaN  16.00000 M    622.00000 H    4.71000 D
# 13404  0.36000 L            NaN  30.00000 H    690.00000 VH   2.47000 D
# 13405  0.38000 L            NaN  19.00000 M    205.00000 M    0.94000 D
# 13406  0.28000 L            NaN  44.00000 VH   232.00000 M    5.69000 D
# 13407  0.34000 L            NaN  26.00000 H    896.00000 VH   4.11000 D
# 13408  0.14000 VL           NaN  11.00000 M    690.00000 VH   3.07000 D
# 13409  0.20000 VL           NaN  39.00000 H    236.00000 M    2.69000 D
# 13410  0.23000 VL           NaN  27.00000 H    393.00000 H    2.47000 D
# 13411  0.23000 VL           NaN   9.00000 L    434.00000 H    2.92000 D
# 13412  0.27000 L            NaN  46.00000 VH   690.00000 VH   3.14000 D
# 13413  0.22000 VL           NaN  20.00000 M    296.00000 M    3.14000 D
# 13414  0.41000 L            NaN  30.00000 H    735.00000 VH   3.22000 D
# 13415  0.28000 L            NaN  17.00000 M    616.00000 H    3.81000 D
# 13416  0.27000 L            NaN  33.00000 H    430.00000 H    1.94000 D
# 13417  0.30000 L            NaN  25.00000 M    473.00000 H    3.07000 D
# 13418  0.22000 VL           NaN  13.00000 M    350.00000 H    4.90000 D
# 13419  0.23000 VL           NaN  68.00000 VH   795.00000 VH   1.27000 D
# 13420  0.41000 L            NaN  21.00000 M    457.00000 H    1.89000 D
# 13421  0.64000 M            NaN  64.00000 VH   759.00000 VH   5.76000 D
# 13422  0.41000 L            NaN  32.00000 H    227.00000 M    4.11000 D
# 13423  0.19000 VL           NaN  58.00000 VH   353.00000 H    1.57000 D
# 13424  0.32000 L            NaN  19.00000 M    473.00000 H    1.64000 D
# 13425  0.21000 VL           NaN  26.00000 H    420.00000 H    3.14000 D
#
#               Zn          Fe         Cu          Mn          B
# 1            NaN         NaN        NaN         NaN        NaN
# 3      0.96000 S   3.62000 D  1.26000 S  16.32000 S  1.32000 S
# 4      0.85000 S   5.26000 S  3.20000 S  18.52000 S  1.52000 S
# 5      0.87000 S   5.31000 S  2.61000 S  21.30000 S  1.62000 S
# 6      0.84000 S   4.22000 D  5.31000 S  22.30000 S  0.95000 S
# 7      0.75000 S   4.01000 D  4.21000 S  17.26000 S  0.98000 S
# 8      0.52000 D   4.32000 D  4.02000 S  22.36000 S  0.97000 S
# 9      0.85000 S   5.26000 S  4.06000 S  18.00000 S  1.65000 S
# 10     0.65000 S   5.31000 S  3.21000 S  19.65000 S  1.45000 S
# 5      0.53000 M   367.50000 M   15.24000 M    510.94000 H    6.31000 D
# 6      1.08000 VH  756.00000 VH  15.72000 M    656.54000 H    5.26000 D
# 7      0.81000 H   567.00000 H   21.05000 M    644.34000 H    7.62000 D
# 8      0.89000 H   619.50000 H   18.14000 M    589.34000 H    5.22000 D
# 9      0.75000 M   525.00000 M   22.98000 M    711.42000 VH   4.62000 D
# 10     0.77000 H   535.50000 M   15.72000 M    607.71000 H    5.31000 D
# 11     0.74000 M   515.60000 M   10.40000 M    716.24000 VH   4.20000 D
# 12     0.75000 M   525.00000 M   19.84000 M    660.35000 H    5.62000 D
# 13     0.62000 M   430.50000 M   21.05000 M    663.04000 H   10.30000 S
# 14     0.60000 M   420.00000 M   15.48000 M    488.54000 H   62.53000 S
# 15     0.65000 M   451.50000 M   22.98000 M    730.69000 VH   4.21000 D
# 16     0.78000 H   546.00000 M   15.00000 M    847.17000 VH   9.62000 D
# 17     0.68000 M   472.50000 M   17.42000 M    287.06000 M    9.53000 D
# 18     0.68000 M   472.50000 M   20.56000 M    656.77000 H    8.64500 D
# 19     0.84000 H   588.00000 H   14.27000 M    843.58000 VH   0.98000 D
# 20     0.83000 H   577.50000 H   22.98000 M    656.77000 H    7.32000 D
# 21     0.99000 H   693.00000 H   20.56000 M    731.58000 VH   0.95000 D
# 22     0.65000 M   451.50000 M   12.82000 M    700.34000 VH   0.99000 D
# 23     0.48000 L   336.00000 M   18.14000 M   6380.42000 VH  11.99000 S
# 24     0.65000 M   451.50000 M   19.11000 M    521.02000 H   13.39000 S
# 25     0.68000 M   472.50000 M   21.05000 M    545.10000 H   15.91000 S
# 26     0.78000 H   546.00000 M   22.50000 M    731.58000 VH   6.32000 D
# 27     0.78000 H   546.00000 M   16.21000 M    959.17000 VH  12.39000 S
# 28     0.65000 M   451.50000 M   14.27000 M    846.94000 VH  10.99000 S
# 29     0.98000 H   682.50000 H   12.34000 M    789.71000 VH  14.51000 S
# ...           ...           ...          ...            ...         ...
# 13233  0.30000 L            NaN  62.00000 VH   217.00000 M    3.14000 D
# 13234  0.18000 VL           NaN  17.00000 M    217.00000 M    3.89000 D
# 13235  0.33000 L            NaN  53.00000 VH   224.00000 M    3.22000 D
# 13236  0.22000 VL           NaN  20.00000 M    349.00000 H    4.19000 D
# 13237  0.37000 L            NaN  48.00000 VH   342.00000 H    3.14000 D
# 13238  0.21000 VL           NaN  20.00000 M    471.00000 H    2.69000 D
# 13239  0.42000 L            NaN  29.00000 H    483.00000 H    3.81000 D
# 13240  0.24000 VL           NaN  16.00000 M    622.00000 H    4.71000 D
# 13241  0.36000 L            NaN  30.00000 H    690.00000 VH   2.47000 D
# 13242  0.38000 L            NaN  19.00000 M    205.00000 M    0.94000 D
# 13243  0.28000 L            NaN  44.00000 VH   232.00000 M    5.69000 D
# 13244  0.34000 L            NaN  26.00000 H    896.00000 VH   4.11000 D
# 13245  0.14000 VL           NaN  11.00000 M    690.00000 VH   3.07000 D
# 13246  0.20000 VL           NaN  39.00000 H    236.00000 M    2.69000 D
# 13247  0.23000 VL           NaN  27.00000 H    393.00000 H    2.47000 D
# 13248  0.23000 VL           NaN   9.00000 L    434.00000 H    2.92000 D
# 13249  0.27000 L            NaN  46.00000 VH   690.00000 VH   3.14000 D
# 13250  0.22000 VL           NaN  20.00000 M    296.00000 M    3.14000 D
# 13251  0.41000 L            NaN  30.00000 H    735.00000 VH   3.22000 D
# 13252  0.28000 L            NaN  17.00000 M    616.00000 H    3.81000 D
# 13253  0.27000 L            NaN  33.00000 H    430.00000 H    1.94000 D
# 13254  0.30000 L            NaN  25.00000 M    473.00000 H    3.07000 D
# 13255  0.22000 VL           NaN  13.00000 M    350.00000 H    4.90000 D
# 13256  0.23000 VL           NaN  68.00000 VH   795.00000 VH   1.27000 D
# 13257  0.41000 L            NaN  21.00000 M    457.00000 H    1.89000 D
# 13258  0.64000 M            NaN  64.00000 VH   759.00000 VH   5.76000 D
# 13259  0.41000 L            NaN  32.00000 H    227.00000 M    4.11000 D
# 13260  0.19000 VL           NaN  58.00000 VH   353.00000 H    1.57000 D
# 13261  0.32000 L            NaN  19.00000 M    473.00000 H    1.64000 D
# 13262  0.21000 VL           NaN  26.00000 H    420.00000 H    3.14000 D
#
#               Zn          Fe         Cu          Mn          B
# 0            NaN         NaN        NaN         NaN        NaN
# 1      0.96000 S   3.62000 D  1.26000 S  16.32000 S  1.32000 S
# 2      0.85000 S   5.26000 S  3.20000 S  18.52000 S  1.52000 S
# 3      0.87000 S   5.31000 S  2.61000 S  21.30000 S  1.62000 S
# 4      0.84000 S   4.22000 D  5.31000 S  22.30000 S  0.95000 S
# 5      0.75000 S   4.01000 D  4.21000 S  17.26000 S  0.98000 S
# 6      0.52000 D   4.32000 D  4.02000 S  22.36000 S  0.97000 S
# 7      0.85000 S   5.26000 S  4.06000 S  18.00000 S  1.65000 S
# 8      0.65000 S   5.31000 S  3.21000 S  19.65000 S  1.45000 S
# 9      0.53000 D   5.62000 S  2.65000 S  19.81000 S  2.02000 S
# 10     0.95000 S   5.62000 S  3.55000 S  18.63000 S  1.63000 S
# 11     0.84000 S   5.31000 S  3.21000 S  16.58000 S  0.86000 S
# 12     0.87000 S   4.26000 D  3.66000 S  20.65000 S  1.46000 S
# 13     0.85000 S   6.52000 S  5.21000 S  14.25000 S  1.75000 S
# 14     0.98000 S   5.31000 S  2.31000 S  18.43000 S  1.56000 S
# 15     0.85000 S   4.26000 D  2.65000 S  19.66000 S  0.29000 D
# 16     0.63000 S   5.60000 S  4.20000 S  17.23000 S  1.44000 S
# 17     0.95000 S   6.32000 S  4.51000 S  23.96000 S  0.89000 S
# 18     0.82000 S   5.32000 S  4.25000 S  16.32000 S  0.52000 S
# 19     0.62000 S   6.52000 S  5.31000 S  22.79000 S  1.42000 S
# 20     0.85000 S  76.32000 S  6.32000 S  19.81000 S  1.67000 S
# 21     0.64000 S   5.32000 S  2.30000 S  23.76000 S  1.44000 S
# 22     0.72000 S   2.31000 D  2.31000 S  23.42000 S  1.23000 S
# 23     0.53000 D   5.62000 S  4.21000 S  20.00000 S  0.87000 S
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
import pandas as pd
import numpy as np
import csv
import os
import string

# Path to import file
path1 = "C:/Users/amogh/Desktop/SBMP/6th sem/Project/Dataset/Soil/Soil Contents/Akola/block1.csv"

df_csv = pd.read_csv(path1)  # Load file into dataframe df_csv

df_csv = df_csv.dropna(axis=1, how='all')  # Drop all blank columns
# Filter cond1 drop columns whose first index of sample no is not M
filter1 = df_csv["Sample No."].str[0] == "M"
# Filter cond2 drop columns whose first index of sample no is not V
filter2 = df_csv["Sample No."].str[0] == "V"
df_csv.where(filter1 | filter2, inplace=True)
df_csv = df_csv.dropna(how='all')  # Drop all rows with NaN's

df_csv = df_csv.reset_index(drop=True)  # Reset index for consistency
df_temp1 = df_csv.copy()  # Create a deep copy of df_csv to df_temp1

# Filter cond1 drop columns whose first index of sample no is not M again used to filter out village name
filter1 = df_csv["Sample No."].str[0] == "M"
df_csv.where(filter1, inplace=True)
df_csv = df_csv.dropna(how='all')   # Drop all rows with NaN's

# Filter cond2 drop columns whose first index of sample no is not V again used to keep only village name
filter3 = df_temp1["Sample No."].str[0] == "V"
df_temp1.where(filter3, inplace=True)
df_temp1 = df_temp1.dropna(how="all")   # Drop all rows with Nan's
df_temp1 = df_temp1.dropna(1, how="all")  # Drop all cols with Nan's

# Create a new column index whose value is that of the index column of dataframe
df_csv["index"] = df_csv.index
df_temp1["index"] = df_temp1.index

for cols in df_csv:  # For each column in dataframe apply a regex which replaces all chars with blanks
    df_csv.loc[:, cols].replace(
        regex=True, inplace=True, to_replace=r'[a-zA-Z]', value=r'')

# Create a list of dictionaries where the column header is the key and the column values are stored in a list ie. value of key
new_csv = df_csv.to_dict("list")
new_dict = df_temp1.to_dict("list")

list1 = []
# Create an empty list with key "Village" to add it in the final dataframe
new_csv["Village"] = list1

# Iterate over village names(second last only)
for i in range(0, len(new_dict["index"])-1):
    for j in range(0, len(new_csv["index"])):   # Iterate over samples
        # If index of village name is not present in samples then execute
        if (new_dict["index"][i] not in new_csv["index"]):
            # Find difference between index number of village 1 and village 2 eg. village1.index = 200 village2.index = 350 then 350-200 = 150;
            for k in range(0, (new_dict["index"][i+1] - new_dict["index"][i])-1):
                # execute loop and repeat village name for n times ie. for all samples of that village
                list1.append(new_dict["Sample No."][i])
        break    # Once sample found end searching

# for the last village put here due to index overflow error
# Find difference between last value of sample and last value of village name
for i in range(0, (new_csv["index"][-1]-new_dict["index"][-1])):
    # execute loop and repeat village name for n times ie. for all samples of that village
    list1.append(new_dict["Sample No."][-1])

df_csv = df_csv.from_dict(new_csv)   # import the dictionary to dataframe

cols_Drop = ["Sr.No.", "Sample No.", "EC", "S", "Mn", "Cu", "Zn", "B", "index"]
df_csv = df_csv.drop(cols_Drop, axis=1)  # Drop the above mentioned columns
# Reorder columns in dataframe
df_csv = df_csv[['Village', 'pH', 'N', 'P', 'K', 'OC', 'Fe']]
df_csv = df_csv.dropna()   # Now drop all rows with null values from dataframe
# Reset index to create a final index for dataframe
df_csv = df_csv.groupby("Village").filter(lambda x: len(x) >= 10)  # To remove all villages with less than 10 entries
df_csv = df_csv.reset_index(drop=True)   # Reset index

filter_Letter = string.ascii_letters + ":"
# Filter out Village: from Village: village_name
df_csv["Village"] = df_csv["Village"].map(lambda x: x.lstrip(filter_Letter))
df_csv["Village"] = df_csv["Village"].str.strip()  # Remove whitespace around village name
df_csv = df_csv.astype({"pH": 'float64', "N": 'float64', "P": 'float64',
                        "K": 'float64', "OC": 'float64', "Fe": 'float64'})  # Change column datatype

#def z_score_Clean(ys):
#    threshold = 3.5
#    median_y = np.median(ys)
#    median_absolute_deviation_y = np.median([np.abs(y - median_y) for y in ys])
    
#    for y in ys:
#        modified_z_scores = [0.55 * (y - median_y) / median_absolute_deviation_y]
#        if np.abs(modified_z_scores) > threshold:
#            ys[y] = np.nan
#
#    return ys

def iqrClean(ys):
    
    sorted(ys)
    
    quartile_1, quartile_3 = np.percentile(ys, [25, 75])
    iqr = quartile_3 - quartile_1
    lower_bound = quartile_1 - (iqr * 1.95)
    upper_bound = quartile_3 + (iqr * 1.95)
    
    for y in range(0, len(ys)):
        if (ys[y] > upper_bound) | (ys[y] < lower_bound):
            ys[y] = np.nan
                     
    return ys

df_temp = pd.DataFrame()
village_Names = df_csv.Village.unique()
for i in village_Names:
    hey = df_csv[df_csv.Village == i]
    new_csv = hey.to_dict("list")
    
    for head in new_csv:
        if head != "Village":
            new_csv[head] = iqrClean(new_csv[head])
    
    df_temp = df_temp.append(df_temp.from_dict(new_csv))
    
df_fin = df_temp.groupby("Village").mean()
df_fin
# Out:
#                       pH           N          P            K        OC  \
# Village
# AGAR            7.931921  512.958908  17.241201   698.096558  0.735551
# ALIYABAD        7.865161  354.290323  13.630968   781.004667  0.507097
# AMANATPUR       8.164615  236.775000  16.328378   367.318190  0.335250
# AMBIKAPUR       7.518085  311.341667  11.694628   631.379872  0.441687
# ANAKWADI        8.318889  519.985185   8.716800   567.297083  0.743519
# ANVI            7.870000  174.992258  17.813692   609.121884  0.390373
# APATAPA         8.184022  286.321768  11.442840   786.549040  0.446289
# BABHULGAON JH   8.260690  267.923077  19.694041   871.829967  0.384615
# BAHIRKHED       8.170000  278.558824  29.058824   629.578353  0.398235
# BAKHARABAD      8.276892  331.286667  20.285733   592.402027  0.473067
# BHOD            7.577212  369.687086  14.806186   707.340447  0.639838
# BHOURAT         7.975789  440.132456  12.254393   655.115214  0.629662
# BIRSINGPUR      8.013122  383.615092  19.883748   721.987918  0.612679
# CHANDPUR        7.795325  268.170909  22.381642   875.884117  0.459987
# CHANDUR         8.036277  345.327128  26.966048   689.371968  0.493803
# DABKI           8.365098  413.538462  13.642157   593.750962  0.592885
# DAHIHANDA       8.289730  724.355814  15.889024   602.096279  1.033023
# DALAMBI         7.759655  161.414444  20.496207   832.846897  0.492069
# DAPURA          8.449000  338.229091  30.399436   766.725091  0.530000
# DEVLI           7.576032  604.146154  13.879355   983.026492  0.859531
# DHAMNA          7.811028  264.653832  21.166925   582.422804  0.460093
# DHOTARDI        8.451026  438.513158  16.908247   641.249778  0.623974
# DODAKI          7.897879  344.893030  13.216786   663.477273  0.516970
# DONGARGAON      8.455312  326.484375  15.717458   616.234182  0.466563
# DUDHALA         8.110833  318.444583  23.149583   735.574062  0.564583
# DUDHALAM        7.942476  253.562095  13.648208   690.663276  0.483476
# GANORI          2.106842
# GHONGA          2.868667
# ...                  ...
# RAMBHAPUR       5.516552
# RAMGAON         8.203929
# ROHANA          4.095946
# SANGAVI BK      4.690000
# SANGLUD BK      3.137847
# SANGVI KH       2.647895
# SHAHAPUR        4.667879
# SHAMABAD        2.433077
# SHILODA         2.016000
# SHIWAPUR        8.040849
# SOMTHANA        3.173750
# SONALA          4.559440
# SUKALI          3.055429
# SUKODA          5.137023
# TAKLI POTE      4.217333
# TAKODA          6.092414
# TAMSHI          3.963333
# TANKHED         3.891124
# UGWA            3.223175
# UKLI            1.724800
# WADAD BK        4.428000
# WADAD KH        2.896923
# WAIRAT RAJAPUR  4.763226
# WAKAPUR         1.533170
# WALKI           3.797568
# WARODI          4.424400
# WASHIMBA        4.131667
# YAWALKHED       3.106604
# YELWAN          3.846364
# YEOTA           5.262222
#
# [118 rows x 6 columns]

# %%
type(df_csv)
# Out:
# pandas.core.frame.DataFrame

# %%
import pandas as pd
import numpy as np
import csv
import os
import string


def dirNames(path):

    dirs_List = []
    file_List = []

    for roots, dirs, files in os.walk(path):  # SCAN FILES
        dirs_List.append(dirs)
        file_List.append(files)

    return dirs_List, file_List


def makePath(path, dir_List, file_List):

    df_Fin = pd.DataFrame()
    i = 0

    for j in range(1, len(file_List)):
        while i < len(dir_List[0]):
            init_Path = os.path.join(path, dir_List[0][i])
            for k in file_List[j]:
                fin_Path = os.path.join(init_Path, k)
                df_Csv = dataClean(fin_Path)
                df_Fin = df_Fin.append(df_Csv)
            
            clean_File_Path = f"../Dataset/Final soil_Village/{dir_List[0][i]}.csv"
            saveFile(clean_File_Path, df_Fin)
            i += 1
            break


# def z_score_Clean(data_List):
"""
    Summary:
            To clean outliers from data using z-score, less accurate

    Arguments:
            data_List {list} -- Sub-setted village-wise list

    Returns:
            data_List {list} -- Cleaned list subset
    """
#    threshold = 3.5
#    median_y = np.median(data_List)
#    median_absolute_deviation_y = np.median([np.abs(data - median_y) for data in data_List])

#    for data in data_List:
#        modified_z_scores = [0.55 * (data - median_y) / median_absolute_deviation_y]
#        if np.abs(modified_z_scores) > threshold:
#            data_List[data] = np.nan
#
#    return data_List


def iqrClean(data_List):
    """
    Summary:
            To clean outliers from data using IQR, more accurate

    Arguments:
            data_List {list} -- Sub-setted village-wise list

    Returns:
            data_List {list} -- Cleaned list subset
    """

    sorted(data_List)  # Sort data to find IQR

    lower_Quartile, upper_Quartile = np.percentile(
        data_List, [25, 75])  # Finding upper and lower quartile
    iqr = upper_Quartile - lower_Quartile  # Finding inter-quartile range
    lower_Bound = lower_Quartile - (iqr * 1.95)  # Find lower bound/level
    upper_Bound = upper_Quartile + (iqr * 1.95)  # Find upper bound/level

    for data in range(0, len(data_List)):   # To iterate over whole data_List
        # Check if data is out of bounds
        if (data_List[data] > upper_Bound) | (data_List[data] < lower_Bound):
            data_List[data] = np.nan  # Make out of bounds data Nan

    return data_List  # Return Data List

def dataClean(csv_Path):
    df_Csv = pd.read_csv(csv_Path)  # Load file into DataFrame df_Csv

    df_Csv = df_Csv.dropna(axis=1, how="all")  # Drop all blank columns
    # filter_Cond cond1 drop columns whose first index of sample no is not M
    filter_Cond1 = df_Csv["Sample No."].str[0] == "M"
    # filter_Cond cond2 drop columns whose first index of sample no is not V
    filter_Cond2 = df_Csv["Sample No."].str[0] == "V"
    df_Csv.where(filter_Cond1 | filter_Cond2, inplace=True)
    df_Csv = df_Csv.dropna(how="all")  # Drop all rows with NaN"s

    df_Csv = df_Csv.reset_index(drop=True)  # Reset index for consistency
    df_Temp1 = df_Csv.copy()  # Create a deep copy of df_Csv to df_Temp1

    # filter_Cond cond1 drop columns whose first index of sample no is not M again used to filter_Cond out village name
    filter_Cond1 = df_Csv["Sample No."].str[0] == "M"
    df_Csv.where(filter_Cond1, inplace=True)
    df_Csv = df_Csv.dropna(how="all")   # Drop all rows with NaN"s

    # filter_Cond cond2 drop columns whose first index of sample no is not V again used to keep only village name
    filter_Cond3 = df_Temp1["Sample No."].str[0] == "V"
    df_Temp1.where(filter_Cond3, inplace=True)
    df_Temp1 = df_Temp1.dropna(how="all")   # Drop all rows with Nan"s
    df_Temp1 = df_Temp1.dropna(1, how="all")  # Drop all cols with Nan"s

    # Create a new column index whose value is that of the index column of DataFrame
    df_Csv["index"] = df_Csv.index
    df_Temp1["index"] = df_Temp1.index

    for cols in df_Csv:  # For each column in DataFrame apply a regex which replaces all chars with blanks
        df_Csv.loc[:, cols].replace(
            regex=True, inplace=True, to_replace=r"[a-zA-Z]", value=r"")

    # Create a list of dictionaries where the column header is the key and the column values are stored in a list ie. value of key
    df_Csv_Dict = df_Csv.to_dict("list")
    df_Temp_Dict = df_Temp1.to_dict("list")

    villages_List = []
    # Create an empty list with key "Village" to add it in the final DataFrame
    df_Csv_Dict["Village"] = villages_List

    # Iterate over village names(second last only)
    for i in range(0, len(df_Temp_Dict["index"])-1):
        for j in range(0, len(df_Csv_Dict["index"])):   # Iterate over samples
            # If index of village name is not present in samples then execute
            if (df_Temp_Dict["index"][i] not in df_Csv_Dict["index"]):
                # Find difference between index number of village 1 and village 2 eg. village1.index = 200 village2.index = 350 then 350-200 = 150;
                for k in range(0, (df_Temp_Dict["index"][i+1] - df_Temp_Dict["index"][i])-1):
                    # execute loop and repeat village name for n times ie. for all samples of that village
                    villages_List.append(df_Temp_Dict["Sample No."][i])
            break    # Once sample found end searching

    # for the last village put here due to index overflow error
    # Find difference between last value of sample and last value of village name
    for i in range(0, (df_Csv_Dict["index"][-1]-df_Temp_Dict["index"][-1])):
        # execute loop and repeat village name for n times ie. for all samples of that village
        villages_List.append(df_Temp_Dict["Sample No."][-1])

    # import the dictionary to DataFrame
    df_Csv = df_Csv.from_dict(df_Csv_Dict)

    cols_Drop = ["Sr.No.", "Sample No.", "EC",
                 "S", "Mn", "Cu", "Zn", "B", "index"]
    df_Csv = df_Csv.drop(cols_Drop, axis=1)  # Drop the above mentioned columns
    # Reorder columns in DataFrame
    df_Csv = df_Csv[["Village", "pH", "N", "P", "K", "OC", "Fe"]]
    df_Csv = df_Csv.dropna()  # Now drop all rows with null values from DataFrame

    # To remove all villages with less than 10 entries
    df_Csv = df_Csv.groupby("Village").filter(lambda x: len(x) >= 10)
    # Reset index to create a final index for DataFrame
    df_Csv = df_Csv.reset_index(drop=True)

    filter_Cond_Letter = string.ascii_letters + ":"
    # filter_Cond out Village: from Village: village_name
    df_Csv["Village"] = df_Csv["Village"].map(
        lambda x: x.lstrip(filter_Cond_Letter))
    # Remove whitespace around village name
    df_Csv["Village"] = df_Csv["Village"].str.strip()
    df_Csv = df_Csv.astype({"pH": "float64", "N": "float64", "P": "float64",
                            "K": "float64", "OC": "float64", "Fe": "float64"})  # Change columns datatype to access as numbers

    df_Temp2 = pd.DataFrame()  # Creating new DataFrame
    village_Names = df_Csv.Village.unique()  # Extract village names
    for i in village_Names:  # To iterate over village list
        # Subsetting main DataFrame village wise
        sub_Csv = df_Csv[df_Csv.Village == i]
        df_Csv_Dict = sub_Csv.to_dict("list")

        for iter in df_Csv_Dict:  # To iterate over each column header
            if iter != "Village":  # If the header is not the Village name
                # Call iqrClean() or z_score_Clean() to remove outliers and put the data back into dictionary
                df_Csv_Dict[iter] = iqrClean(df_Csv_Dict[iter])

        df_Temp2 = df_Temp2.append(df_Temp2.from_dict(
            df_Csv_Dict))  # Append value of df_Csv_Dict to df_Temp1 to create final DataFrame

    # Group final cleaned data by Village and find its mean
    df_Csv = df_Temp2.groupby("Village").mean()
    return df_Csv


def saveFile(save_Path, df_Fin):
    df_Fin.to_csv(save_Path)


if __name__ == "__main__":
    # Path to import file
    main_Path = "C:/Users/amogh/Desktop/SBMP/6th sem/Project/Dataset/Soil/"
    dir_List, file_List = dirNames(main_Path)

    # print(dir_List[0][0])
    makePath(main_Path, dir_List, file_List)
# Out:
# <class 'str'>
# C:/Users/amogh/Desktop/SBMP/6th sem/Project/Dataset/Soil/Akola/block1.csv
# None
# Empty DataFrame
# Columns: []
# Index: []
# <class 'str'>
# C:/Users/amogh/Desktop/SBMP/6th sem/Project/Dataset/Soil/Akola/block2 - NSVW (28).csv
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sample No.'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-211-4d2f428a7ac8> in <module>
#     201
#     202     # print(dir_List[0][0])
# --> 203     makePath(main_Path, dir_List, file_List)
#
# <ipython-input-211-4d2f428a7ac8> in makePath(path, dir_List, file_List)
#      30                 print(type(fin_Path))
#      31                 print(fin_Path)
# ---> 32                 df_Csv = dataClean(fin_Path)
#      33                 print(df_Csv)
#      34                 df_Fin = df_Fin.append(df_Csv)
#
# <ipython-input-211-4d2f428a7ac8> in dataClean(path1)
#      95     df_Csv = df_Csv.dropna(axis=1, how="all")  # Drop all blank columns
#      96     # filter_Cond cond1 drop columns whose first index of sample no is not M
# ---> 97     filter_Cond1 = df_Csv["Sample No."].str[0] == "M"
#      98     # filter_Cond cond2 drop columns whose first index of sample no is not V
#      99     filter_Cond2 = df_Csv["Sample No."].str[0] == "V"
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sample No.'

# %%
"C:/Users/amogh/Desktop/SBMP/6th sem/Project/Dataset/Soil/Soil Contents/Akola/block1.csv"
# Out:
# 1.3392857142857142

# %%
temp = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v
# 13147    NaN           NaN         NaN  NaN          NaN           NaN
# 13148    NaN           NaN         NaN  NaN          NaN           NaN
# 13149    NaN           NaN         NaN  NaN          NaN           NaN
# 13150    NaN           NaN         NaN  NaN          NaN           NaN
# 13151    NaN           NaN         NaN  NaN          NaN           NaN
#
#               Fe    index         Village
# 13094  4.48000 D  13262.0  Village: YEOTA
# 13095        NaN      NaN  Village: YEOTA
# 13096        NaN      NaN  Village: YEOTA
# 13097        NaN      NaN  Village: YEOTA
# 13098        NaN      NaN  Village: YEOTA
# 13099        NaN      NaN  Village: YEOTA
# 13100        NaN      NaN  Village: YEOTA
# 13101        NaN      NaN  Village: YEOTA
# 13102        NaN      NaN  Village: YEOTA
# 13103        NaN      NaN  Village: YEOTA
# 13104        NaN      NaN  Village: YEOTA
# 13105        NaN      NaN  Village: YEOTA
# 13106        NaN      NaN  Village: YEOTA
# 13107        NaN      NaN  Village: YEOTA
# 13108        NaN      NaN  Village: YEOTA
# 13109        NaN      NaN  Village: YEOTA
# 13110        NaN      NaN  Village: YEOTA
# 13111        NaN      NaN  Village: YEOTA
# 13112        NaN      NaN  Village: YEOTA
# 13113        NaN      NaN  Village: YEOTA
# 13114        NaN      NaN  Village: YEOTA
# 13115        NaN      NaN  Village: YEOTA
# 13116        NaN      NaN  Village: YEOTA
# 13117        NaN      NaN  Village: YEOTA
# 13118        NaN      NaN  Village: YEOTA
# 13119        NaN      NaN  Village: YEOTA
# 13120        NaN      NaN  Village: YEOTA
# 13121        NaN      NaN  Village: YEOTA
# 13122        NaN      NaN  Village: YEOTA
# 13123        NaN      NaN  Village: YEOTA
# 13124        NaN      NaN  Village: YEOTA
# 13125        NaN      NaN  Village: YEOTA
# 13126        NaN      NaN  Village: YEOTA
# 13127        NaN      NaN  Village: YEOTA
# 13128        NaN      NaN  Village: YEOTA
# 13129        NaN      NaN  Village: YEOTA
# 13130        NaN      NaN  Village: YEOTA
# 13131        NaN      NaN  Village: YEOTA
# 13132        NaN      NaN  Village: YEOTA
# 13133        NaN      NaN  Village: YEOTA
# 13134        NaN      NaN  Village: YEOTA
# 13135        NaN      NaN  Village: YEOTA
# 13136        NaN      NaN  Village: YEOTA
# 13137        NaN      NaN  Village: YEOTA
# 13138        NaN      NaN  Village: YEOTA
# 13139        NaN      NaN  Village: YEOTA
# 13140        NaN      NaN  Village: YEOTA
# 13141        NaN      NaN  Village: YEOTA
# 13142        NaN      NaN  Village: YEOTA
# 13143        NaN      NaN  Village: YEOTA
# 13144        NaN      NaN  Village: YEOTA
# 13145        NaN      NaN  Village: YEOTA
# 13146        NaN      NaN  Village: YEOTA
# 13147        NaN      NaN  Village: YEOTA
# 13148        NaN      NaN  Village: YEOTA
# 13149        NaN      NaN  Village: YEOTA
# 13150        NaN      NaN  Village: YEOTA
# 13151        NaN      NaN  Village: YEOTA

# %%
import pandas as pd
import numpy as np
import csv
import os
import string

def dirNames(path):

    dirs_List = []
    file_List = []

    for roots, dirs, files in os.walk(path):  # SCAN FILES
        dirs_List.append(dirs)
        file_List.append(files)

    return dirs_List, file_List


def makePath(path, dir_List, file_List):

    df_Fin = pd.DataFrame()
    i = 0

    for j in range(1, len(file_List)):
        while i < len(dir_List[0]):
            init_Path = os.path.join(path, dir_List[0][i])
            for k in file_List[j]:
                fin_Path = os.path.join(init_Path, k)
                df_Csv = dataClean(fin_Path)

                df_Fin = df_Fin.append(df_Csv)

            clean_File_Path = f"../Dataset/Final soil_Village/{dir_List[0][i]}.csv"
            saveFile(clean_File_Path, df_Fin)
            i += 1
            break


def dataClean(csv_Path):
    df_Csv = pd.read_csv(csv_Path)  # Load file into DataFrame df_Csv

    df_Csv = df_Csv.dropna(axis=1, how="all")  # Drop all blank columns
    # filter_Cond cond1 drop columns whose first index of sample no is not M
    filter_Cond1 = df_Csv["Sample No."].str[0] == "M"
    # filter_Cond cond2 drop columns whose first index of sample no is not V
    filter_Cond2 = df_Csv["Sample No."].str[0] == "V"
    df_Csv.where(filter_Cond1 | filter_Cond2, inplace=True)
    df_Csv = df_Csv.dropna(how="all")  # Drop all rows with NaN"s

    df_Csv = df_Csv.reset_index(drop=True)  # Reset index for consistency
    df_Temp1 = df_Csv.copy()  # Create a deep copy of df_Csv to df_Temp1

    # filter_Cond cond1 drop columns whose first index of sample no is not M again used to filter_Cond out village name
    filter_Cond1 = df_Csv["Sample No."].str[0] == "M"
    df_Csv.where(filter_Cond1, inplace=True)
    df_Csv = df_Csv.dropna(how="all")   # Drop all rows with NaN"s

    # filter_Cond cond2 drop columns whose first index of sample no is not V again used to keep only village name
    filter_Cond3 = df_Temp1["Sample No."].str[0] == "V"
    df_Temp1.where(filter_Cond3, inplace=True)
    df_Temp1 = df_Temp1.dropna(how="all")   # Drop all rows with Nan"s
    df_Temp1 = df_Temp1.dropna(1, how="all")  # Drop all cols with Nan"s

    # Create a new column index whose value is that of the index column of DataFrame
    df_Csv["index"] = df_Csv.index
    df_Temp1["index"] = df_Temp1.index

    for cols in df_Csv:  # For each column in DataFrame apply a regex which replaces all chars with blanks
        df_Csv.loc[:, cols].replace(
            regex=True, inplace=True, to_replace=r"[a-zA-Z]", value=r"")

    # Create a list of dictionaries where the column header is the key and the column values are stored in a list ie. value of key
    df_Csv_Dict = df_Csv.to_dict("list")
    df_Temp_Dict = df_Temp1.to_dict("list")

    villages_List = []
    # Create an empty list with key "Village" to add it in the final DataFrame
    df_Csv_Dict["Village"] = villages_List

    # Iterate over village names(second last only)
    for i in range(0, len(df_Temp_Dict["index"])-1):
        for j in range(0, len(df_Csv_Dict["index"])):   # Iterate over samples
            # If index of village name is not present in samples then execute
            if (df_Temp_Dict["index"][i] not in df_Csv_Dict["index"]):
                # Find difference between index number of village 1 and village 2 eg. village1.index = 200 village2.index = 350 then 350-200 = 150;
                for k in range(0, (df_Temp_Dict["index"][i+1] - df_Temp_Dict["index"][i])-1):
                    # execute loop and repeat village name for n times ie. for all samples of that village
                    villages_List.append(df_Temp_Dict["Sample No."][i])
            break    # Once sample found end searching

    # for the last village put here due to index overflow error
    # Find difference between last value of sample and last value of village name
    for i in range(0, (df_Csv_Dict["index"][-1]-df_Temp_Dict["index"][-1])):
        # execute loop and repeat village name for n times ie. for all samples of that village
        villages_List.append(df_Temp_Dict["Sample No."][-1])

    df_Csv = df_Csv.from_dict(df_Csv_Dict)   # import the dictionary to DataFrame

    cols_Drop = ["Sr.No.", "Sample No.", "EC", "S", "Mn", "Cu", "Zn", "B", "index"]
    df_Csv = df_Csv.drop(cols_Drop, axis=1)  # Drop the above mentioned columns
    # Reorder columns in DataFrame
    df_Csv = df_Csv[["Village", "pH", "N", "P", "K", "OC", "Fe"]]
    df_Csv = df_Csv.dropna()  # Now drop all rows with null values from DataFrame

    # To remove all villages with less than 10 entries
    df_Csv = df_Csv.groupby("Village").filter(lambda x: len(x) >= 10)
    # Reset index to create a final index for DataFrame
    df_Csv = df_Csv.reset_index(drop=True)

    filter_Cond_Letter = string.ascii_letters + ":"
    # filter_Cond out Village: from Village: village_name
    df_Csv["Village"] = df_Csv["Village"].map(
        lambda x: x.lstrip(filter_Cond_Letter))
    # Remove whitespace around village name
    df_Csv["Village"] = df_Csv["Village"].str.strip()
    df_Csv = df_Csv.astype({"pH": "float64", "N": "float64", "P": "float64",
                            "K": "float64", "OC": "float64", "Fe": "float64"})  # Change columns datatype to access as numbers

    df_Temp2 = pd.DataFrame()  # Creating new DataFrame
    village_Names = df_Csv.Village.unique()  # Extract village names
    for i in village_Names:  # To iterate over village list
        # Subsetting main DataFrame village wise
        sub_Csv = df_Csv[df_Csv.Village == i]
        df_Csv_Dict = sub_Csv.to_dict("list")

        for iter in df_Csv_Dict:  # To iterate over each column header
            if iter != "Village":  # If the header is not the Village name
                # Call iqrClean() or z_score_Clean() to remove outliers and put the data back into dictionary
                df_Csv_Dict[iter] = iqrClean(df_Csv_Dict[iter])

        df_Temp2 = df_Temp2.append(df_Temp2.from_dict(
            df_Csv_Dict))  # Append value of df_Csv_Dict to df_Temp1 to create final DataFrame

    # Group final cleaned data by Village and find its mean
    df_Csv = df_Temp2.groupby("Village").mean()
    return df_Csv


def saveFile(save_Path, df_Fin):
    df_Fin.to_csv(save_Path)


if __name__ == "__main__":
    # Path to import file
    main_Path = "../Dataset/Soil/"
    dir_List, file_List = dirNames(main_Path)

    # print(dir_List[0][0])
    makePath(main_Path, dir_List, file_List)
# Out:
#                       pH           N          P            K        OC  \
# Village
# AGAR            7.931921  512.958908  17.241201   698.096558  0.735551
# ALIYABAD        7.865161  354.290323  13.630968   781.004667  0.507097
# AMANATPUR       8.164615  236.775000  16.328378   367.318190  0.335250
# AMBIKAPUR       7.518085  311.341667  11.694628   631.379872  0.441687
# ANAKWADI        8.318889  519.985185   8.716800   567.297083  0.743519
# ANVI            7.870000  174.992258  17.813692   609.121884  0.390373
# APATAPA         8.184022  286.321768  11.442840   786.549040  0.446289
# BABHULGAON JH   8.260690  267.923077  19.694041   871.829967  0.384615
# BAHIRKHED       8.170000  278.558824  29.058824   629.578353  0.398235
# BAKHARABAD      8.276892  331.286667  20.285733   592.402027  0.473067
# BHOD            7.577212  369.687086  14.806186   707.340447  0.639838
# BHOURAT         7.975789  440.132456  12.254393   655.115214  0.629662
# YELWAN          7.725630  606.736017  14.209478   424.250083  0.859244
# YEOTA           8.057027  297.500000  29.948550   741.918667  0.425139
#
#                       Fe
# Village
# AGAR            4.135087
# ALIYABAD        8.109677
# AMANATPUR       3.744878
# AMBIKAPUR       5.345000
# ANAKWADI        6.177037
# ANVI            2.965652
# APATAPA         6.275101
# BABHULGAON JH   2.334396
# BAHIRKHED       2.647333
# BAKHARABAD      5.362933
# BHOD            2.621143
# BHOURAT         4.522807
# BIRSINGPUR      3.514759
# CHANDPUR        2.315000
# CHANDUR         3.495135
# DABKI           3.433269
# DAHIHANDA       3.865610
# DALAMBI         2.171407
# DAPURA          5.413000
# DEVLI           4.118154
# DHAMNA          2.548519
# DHOTARDI        4.430256
# DODAKI          3.160000
# DONGARGAON      6.118788
# DUDHALA         1.198462
# DUDHALAM        3.937822
# EAKLARA         3.703672
# GANDHIGRAM      5.436579
# GANORI          2.106842
# GHONGA          2.868667
# ...                  ...
# RAMBHAPUR       5.516552
# RAMGAON         8.203929
# ROHANA          4.095946
# SANGAVI BK      4.690000
# SANGLUD BK      3.137847
# SANGVI KH       2.647895
# SHAHAPUR        4.667879
# SHAMABAD        2.433077
# SHILODA         2.016000
# SHIWAPUR        8.040849
# SOMTHANA        3.173750
# SONALA          4.559440
# SUKALI          3.055429
# SUKODA          5.137023
# TAKLI POTE      4.217333
# TAKODA          6.092414
# TAMSHI          3.963333
# TANKHED         3.891124
# UGWA            3.223175
# UKLI            1.724800
# WADAD BK        4.428000
# WADAD KH        2.896923
# WAIRAT RAJAPUR  4.763226
# WAKAPUR         1.533170
# WALKI           3.797568
# WARODI          4.424400
# WASHIMBA        4.131667
# YAWALKHED       3.106604
# YELWAN          3.846364
# YEOTA           5.262222
#
# [118 rows x 6 columns]

# %%
# def z_score_Clean(data_List):
"""
    Summary:
            To clean outliers from data using z-score, less accurate

    Arguments:
            data_List {list} -- Sub-setted village-wise list

    Returns:
            data_List {list} -- Cleaned list subset
    """
#    threshold = 3.5
#    median_y = np.median(data_List)
#    median_absolute_deviation_y = np.median([np.abs(data - median_y) for data in data_List])

#    for data in data_List:
#        modified_z_scores = [0.55 * (data - median_y) / median_absolute_deviation_y]
#        if np.abs(modified_z_scores) > threshold:
#            data_List[data] = np.nan
#
#    return data_List


def iqrClean(data_List):
    """
    Summary:
            To clean outliers from data using IQR, more accurate

    Arguments:
            data_List {list} -- Sub-setted village-wise list

    Returns:
            data_List {list} -- Cleaned list subset
    """

    sorted(data_List)  # Sort data to find IQR

    lower_Quartile, upper_Quartile = np.percentile(
        data_List, [25, 75])  # Finding upper and lower quartile
    iqr = upper_Quartile - lower_Quartile  # Finding inter-quartile range
    lower_Bound = lower_Quartile - (iqr * 1.95)  # Find lower bound/level
    upper_Bound = upper_Quartile + (iqr * 1.95)  # Find upper bound/level

    for data in range(0, len(data_List)):   # To iterate over whole data_List
                # Check if data is out of bounds
        if (data_List[data] > upper_Bound) | (data_List[data] < lower_Bound):
            data_List[data] = np.nan  # Make out of bounds data Nan

    return data_List  # Return Data List
